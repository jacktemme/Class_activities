# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
from scipy.stats import linregress

# %%
# Load vehicle data set into pandas
vehicle_data = pd.read_csv("../Resources/singapore-motor-vehicle-population.csv")
vehicle_data
# Out:
#      year   type                     engine  number
# 0    2006   Cars                     Petrol  471707
# 1    2006   Cars                     Diesel       7
# 2    2006   Cars            Petrol-Electric     379
# 3    2006   Cars  Petrol-Electric (Plug-In)       0
# 4    2006   Cars                 Petrol-CNG     214
# ..    ...    ...                        ...     ...
# 385  2018  Buses            Petrol-Electric       0
# 386  2018  Buses                 Petrol-CNG       0
# 387  2018  Buses                        CNG      12
# 388  2018  Buses                   Electric       4
# 389  2018  Buses            Diesel-Electric      23
#
# [390 rows x 4 columns]

# %%
petrol_df = vehicle_data.loc[vehicle_data["engine"] == "Petrol-Electric"]
petrol_group = petrol_df.groupby("year").sum()
# Out:
#                                         type  \
# year
# 2006  CarsTaxisGoods and Other VehiclesBuses
# 2007  CarsTaxisGoods and Other VehiclesBuses
# 2008  CarsTaxisGoods and Other VehiclesBuses
# 2009  CarsTaxisGoods and Other VehiclesBuses
# 2010  CarsTaxisGoods and Other VehiclesBuses
# 2011  CarsTaxisGoods and Other VehiclesBuses
# 2012  CarsTaxisGoods and Other VehiclesBuses
# 2013  CarsTaxisGoods and Other VehiclesBuses
# 2014  CarsTaxisGoods and Other VehiclesBuses
# 2015  CarsTaxisGoods and Other VehiclesBuses
# 2016  CarsTaxisGoods and Other VehiclesBuses
# 2017  CarsTaxisGoods and Other VehiclesBuses
# 2018  CarsTaxisGoods and Other VehiclesBuses
#
#                                                  engine  number
# year
# 2006  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...     379
# 2007  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    1057
# 2008  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    1999
# 2009  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    2641
# 2010  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    3335
# 2011  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    3843
# 2012  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    4810
# 2013  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    5683
# 2014  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    7336
# 2015  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...    8261
# 2016  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...   12568
# 2017  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...   24911
# 2018  Petrol-ElectricPetrol-ElectricPetrol-ElectricP...   32517

# %%
# Generate a scatter plot of year versus number of petrol-electric cars
x_values = petrol_group.index
y_values = petrol_group["number"]
plt.scatter(x_values,y_values)
plt.xlabel("Year")
plt.ylabel("# of Petrol-Electric Cars")
plt.show()

# %%
# Perform a linear regression on year versus petrol-electric cars
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values
# Out:
# 2093.8241758241757

# %%
# Create equation of line to calculate predicted number of petrol-electric cars

# %%
# Plot the linear model on top of scatter plot

# %%
# Repeat plotting scatter and linear model for year versus petrol cars

# %%
# Repeat plotting scatter and linear model for year versus electric cars

# %%
# Generate a facet plot of all 3 figures

# %%
# Calculate the number of cars for 2024
# Out:
# The number of petrol-electic cars in 2024 will be 27516.0.
# The number of petrol cars in 2024 will be 645370.0.
# The number of diesel cars in 2024 will be 20541.0.
