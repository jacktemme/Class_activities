# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
combined_travel_df = pd.read_csv("Resources/combined_travel.csv")
combined_travel_df.head()
# Out:
#   COUNTRY OF NATIONALITY  2016 Alone  2016 With Spouse  2016 With Children  \
# 0              SINGAPORE        18.6              35.5                 3.9
# 1               THAILAND        30.1              16.7                 0.9
# 2              INDONESIA        12.9              24.6                 3.8
# 3                 BRUNEI        10.2              24.9                 2.2
# 4            PHILIPPINES        13.9              27.5                 1.5
#
#    2016 With Family/Relatives  2016 Student Group  2016 With Friends  \
# 0                        23.7                 0.1               14.7
# 1                        12.0                 3.1               30.2
# 2                        37.9                 0.9               14.9
# 3                        44.5                 0.0               16.2
# 4                        15.0                 5.5               34.1
#
#    2016 With Business Associate  2016 With Incentive Group  2016 Others  ...  \
# ...

# %%
# set up data to use for plot
country_df = combined_travel_df.set_index("COUNTRY OF NATIONALITY")
companion_df = country_df[["2016 Alone","2017 Alone","2018 Alone"]]
companion_df = companion_df.iloc[[0,2,18]]
companion_df
# Out:
#                         2016 Alone  2017 Alone  2018 Alone
# COUNTRY OF NATIONALITY
# SINGAPORE                     18.6        20.6        16.9
# INDONESIA                     12.9        10.4        11.3
# USA                           29.5        21.7        14.7

# %%
x_axis = [2017,2018,2019]

# %%
plt.plot(x_axis, companion_df.iloc[0].values, color = "green", label = "Singapore")
plt.plot(x_axis, companion_df.iloc[1].values, color = "red", label = "Indonesia" )
plt.plot(x_axis, companion_df.iloc[2].values, color = "blue", label = "USA")
plt.xticks(x_axis)
plt.legend(loc = "upper right")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.title("Traveling Alone Country Comparison")
plt.ylabel ("% of Travelers")
plt.xlabel ("Years")
# Out:
# Text(0.5, 47.04444444444444, 'Years')
