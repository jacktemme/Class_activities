# %%
# %matplotlib widget

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create the X and Y axis lists
time = np.arange(0,130,10)
danger_drop_speeds = [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]
railgun_speeds = [75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]

# %%
# Plot the charts and apply some styling
plt.plot(time,danger_drop_speeds, color = "red", marker = "*", label = "Danger Drop")
plt.plot(time,railgun_speeds, color = "green", marker = "o", label = "Railgun")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Add labels to X and Y axes :: Add title
plt.xlabel("Coaster Runtime (seconds)")
plt.ylabel("Speed (mph)")
plt.title("Coaster Speed Over Time")
# Out:
# Text(0.5, 1.0, 'Coaster Speed Over Time')

# %%
# Set the limits for the X and Y axes
plt.xlim(0,120)
plt.ylim(0,93)
# Out:
# (0.0, 93.0)

# %%
# Create a legend for the chart
plt.legend(loc = "upper right")

# %%
# Add in a grid for the chart

plt.grid()
