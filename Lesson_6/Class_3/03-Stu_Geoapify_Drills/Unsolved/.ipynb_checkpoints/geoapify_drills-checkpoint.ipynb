# %% [markdown]
# # Geoapify Drills
#
# Create code to answer each of the following questions.
#
# > **Hint:** You will need multiple target URLs and multiple API requests.

# %%
# Dependencies
import requests
import json
from pprint import pprint

# Import the API key
from config import geoapify_key

# %% [markdown]
# ## 1. What are the geocoordinates (latitude and longitude) of Brisbane, Australia?

# %%
# Set the search parameters
target_city = "Brisbane, Australia"

# Build URL using the geocode endpoint
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
# Run request

response = requests.get(target_url).json()
# Print the json (pretty printed)
pprint(response)
# Out:
# {'query': {'parsed': {'city': 'brisbane',
#                       'country': 'australia',
#                       'expected_type': 'city'},
#            'text': 'Brisbane, Australia'},
#  'results': [{'address_line1': 'Brisbane City',
#               'address_line2': 'QLD, Australia',
#               'bbox': {'lat1': -27.660219,
#                        'lat2': -27.022014,
#                        'lon1': 152.679693,
#                        'lon2': 153.468275},
#               'category': 'administrative',
#               'city': 'Brisbane City',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Brisbane City, QLD, Australia',
#               'lat': -27.4689682,
#               'lon': 153.0234991,
#               'place_id': '51893f2f81c0206340592eddc94c0e783bc0f00101f9016030b20000000000c00208',
#               'plus_code': '5R4MG2JF+C9',
#               'rank': {'confidence': 0.9,
#                        'confidence_city_level': 0.9,
#                        'importance': 0.8694082277592821,
#                        'match_type': 'full_match',
#                        'popularity': 6.876406158741578},
#               'result_type': 'city',
#               'state': 'Queensland',
#               'state_code': 'QLD',
#               'timezone': {'abbreviation_DST': 'AEST',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Brisbane',
#                            'offset_DST': '+10:00',
#                            'offset_DST_seconds': 36000,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}}]}

# %%
# Extract lat/lon

lat = response["results"][0]["lat"]
lon = response["results"][0]["lon"]
# Print results
print(f'Coordinates for {target_city}: {lat},{lon}')
# Out:
# Coordinates for Brisbane, Australia: -27.4689682,153.0234991

# %% [markdown]
# ## 2. What are the geocoordinates (latitude and longitude) of The Sydney Opera House?

# %%
# update params dict
target_city = "Sydney Opera House"
params = {
    "text": target_city,
    "apiKey": geoapify_key}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request

response = requests.get(base_url, params = params).json()

# Print the json (pretty printed)
pprint(response)
# Out:
# {'features': [{'bbox': [151.214428, -33.8579291, 151.2158894, -33.856305],
#                'geometry': {'coordinates': [151.21512338473752, -33.85719805],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Sydney Opera House',
#                               'address_line2': '2 Macquarie Street, Sydney NSW '
#                                                '2000, Australia',
#                               'category': 'entertainment.culture.arts_centre',
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database License',
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'district': 'Quay Quarter',
#                               'formatted': 'Sydney Opera House, 2 Macquarie '
#                                            'Street, Sydney NSW 2000, Australia',
#                               'housenumber': '2',
#                               'lat': -33.85719805,
#                               'lon': 151.21512338473752,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Sydney Opera House',
#                               'place_id': '51aec16f4ae2e6624059f5786baab8ed40c0f00101f901c86f920000000000c002019203125379646e6579204f7065726120486f757365',
#                               'plus_code': '4RRH46V8+42',
#                               'plus_code_short': 'V8+42 Sydney, New South '
#                                                  'Wales, Australia',
#                               'postcode': '2000',
#                               'rank': {'confidence': 1,
#                                        'importance': 0.8439868225769328,
#                                        'match_type': 'full_match',
#                                        'popularity': 6.979585085597298},
#                               'result_type': 'amenity',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Macquarie Street',
#                               'suburb': 'Sydney',
#                               'timezone': {'abbreviation_DST': 'AEDT',
#                                            'abbreviation_STD': 'AEST',
#                                            'name': 'Australia/Sydney',
#                                            'offset_DST': '+11:00',
#                                            'offset_DST_seconds': 39600,
#                                            'offset_STD': '+10:00',
#                                            'offset_STD_seconds': 36000}},
#                'type': 'Feature'},
#               {'bbox': [-105.0905037, 39.263046, -105.0899454, 39.2632642],
#                'geometry': {'coordinates': [-105.09021131983177, 39.2631531],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Sydney Opera House',
#                               'address_line2': 'Douglas County, CO, United '
#                                                'States of America',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Douglas County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database License',
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'formatted': 'Sydney Opera House, Douglas '
#                                            'County, CO, United States of '
#                                            'America',
#                               'lat': 39.2631531,
#                               'lon': -105.09021131983177,
#                               'name': 'Sydney Opera House',
#                               'place_id': '51031ab305c6455ac059a62b3300afa14340f00102f901a9d8214700000000c002019203125379646e6579204f7065726120486f757365',
#                               'plus_code': '85FP7W75+7W',
#                               'rank': {'confidence': 1,
#                                        'importance': 0.50001,
#                                        'match_type': 'full_match',
#                                        'popularity': 1.8358464436716186},
#                               'result_type': 'amenity',
#                               'state': 'Colorado',
#                               'state_code': 'CO',
#                               'timezone': {'abbreviation_DST': 'MDT',
#                                            'abbreviation_STD': 'MST',
#                                            'name': 'America/Denver',
#                                            'offset_DST': '-06:00',
#                                            'offset_DST_seconds': -21600,
#                                            'offset_STD': '-07:00',
#                                            'offset_STD_seconds': -25200}},
#                'type': 'Feature'},
#               {'bbox': [116.2844042, 39.8077821, 116.2845042, 39.8078821],
#                'geometry': {'coordinates': [116.2844542, 39.8078321],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Sydney Opera House',
#                               'address_line2': '葆台路, Hua‘xiang, 100070 '
#                                                'Beijing, China',
#                               'category': 'tourism.attraction',
#                               'city': 'Fengtai District',
#                               'country': 'China',
#                               'country_code': 'cn',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database License',
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'formatted': 'Sydney Opera House, 葆台路, '
#                                            'Hua‘xiang, 100070 Beijing, China',
#                               'lat': 39.8078321,
#                               'lon': 116.2844542,
#                               'name': 'Sydney Opera House',
#                               'place_id': '516e8d637f34125d40595a14d10a67e74340f00103f9015173cdbd00000000c002019203125379646e6579204f7065726120486f757365',
#                               'plus_code': '8PFRR75M+4Q',
#                               'postcode': '100070',
#                               'rank': {'confidence': 1,
#                                        'importance': 0.30001,
#                                        'match_type': 'full_match',
#                                        'popularity': 2.6769029610356663},
#                               'result_type': 'amenity',
#                               'state': 'Beijing',
#                               'street': '葆台路',
#                               'suburb': 'Hua‘xiang',
#                               'timezone': {'abbreviation_DST': 'CST',
#                                            'abbreviation_STD': 'CST',
#                                            'name': 'Asia/Shanghai',
#                                            'offset_DST': '+08:00',
#                                            'offset_DST_seconds': 28800,
#                                            'offset_STD': '+08:00',
#                                            'offset_STD_seconds': 28800},
#                               'village': '郭公庄村'},
#                'type': 'Feature'}],
#  'query': {'text': 'Sydney Opera House'},
#  'type': 'FeatureCollection'}

# %%
# Extract lat/lon

lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]
# Print results
print(f'Coordinates for {target_city}: {lat},{lon}')
# Out:
# Coordinates for Sydney Opera House: -33.85719805,151.21512338473752

# %% [markdown]
# ## 3. Find the name and address of a pharmacy in Brisbane, Australia.
#
# > **Hint:** Review <https://apidocs.geoapify.com/docs/places/#categories>.

# %%
# Set the geographical coordinates for Brisbane, Australia

lat = -27.4689682
lon = 153.0234991
# Set the parameters for the type of place

categories = "healthcare.pharmacy"
# Set the parameters for the type of search

bias = f'proximity:{lon},{lat}'
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias": bias,
    "apiKey":geoapify_key }

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request

response = requests.get(base_url, params=params).json()
# Print the json (pretty printed)
pprint(response)
# Out:
# {'features': [{'geometry': {'coordinates': [153.024774, -27.46900499946224],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Wizard Pharmacy',
#                               'address_line2': 'Queen Street Mall, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Wizard Pharmacy',
#                                                      'osm_id': 6320207377,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 126,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Wizard Pharmacy, Queen Street '
#                                            'Mall, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'lat': -27.469005,
#                               'lon': 153.024774,
#                               'name': 'Wizard Pharmacy',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '5151f9d7f2ca20634059cf592eb610783bc0f00103f90111b6b6780100000092030f57697a61726420506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street Mall',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02486289999996,
#                                             -27.469754799462155],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '120 Queen Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'brand': 'Priceline Pharmacy',
#                               'brand_details': {'wikidata': 'Q7242652',
#                                                 'wikipedia': 'en:Priceline '
#                                                              '(Australia)'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 1546536181,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 161,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Priceline Pharmacy, 120 Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '120',
#                               'lat': -27.4697548,
#                               'lon': 153.0248629,
#                               'name': 'Priceline Pharmacy',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '5146cc47adcb2063405939d4bcd941783bc0f00103f901f5442e5c0000000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0217986, -27.469351399462198],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Wizard Pharmacy',
#                               'address_line2': '336 George Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Wizard Pharmacy',
#                                                      'osm_id': 1546700978,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 173,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Wizard Pharmacy, 336 George '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '336',
#                               'lat': -27.4693514,
#                               'lon': 153.0217986,
#                               'name': 'Wizard Pharmacy',
#                               'place_id': '512843fa92b220634059a005cf6927783bc0f00103f901b2c8305c0000000092030f57697a61726420506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'George Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0238264, -27.47057739946206],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Chemist Warehouse',
#                               'address_line2': '60 Queen Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'brand': 'Chemist Warehouse',
#                               'brand_details': {'wikidata': 'Q48782120',
#                                                 'wikipedia': 'en:Chemist '
#                                                              'Warehouse'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Chemist '
#                                                               'Warehouse',
#                                                      'brand:wikidata': 'Q48782120',
#                                                      'brand:wikipedia': 'en:Chemist '
#                                                                         'Warehouse',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Chemist '
#                                                              'Warehouse',
#                                                      'osm_id': 5151109719,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 181,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Chemist Warehouse, 60 Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '60',
#                               'lat': -27.4705774,
#                               'lon': 153.0238264,
#                               'name': 'Chemist Warehouse',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '510119952fc32063405920edacc277783bc0f00103f90157b20733010000009203114368656d6973742057617265686f757365',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.027627, -27.468605199462253],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': 'Edward Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'brand': 'Priceline Pharmacy',
#                               'brand_details': {'wikidata': 'Q7242652',
#                                                 'wikipedia': 'en:Priceline '
#                                                              '(Australia)'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 8140167944,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 410,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Priceline Pharmacy, Edward Street, '
#                                            'Brisbane City QLD 4000, Australia',
#                               'lat': -27.4686052,
#                               'lon': 153.027627,
#                               'name': 'Priceline Pharmacy',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '5192af0452e2206340590a6da682f6773bc0f00103f901081b31e50100000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Edward Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02753079999997,
#                                             -27.46753149946238],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Post Office Square Pharmacy',
#                               'address_line2': 'Queen Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'layer': -1,
#                                                      'name': 'Post Office '
#                                                              'Square Pharmacy',
#                                                      'osm_id': 1546982742,
#                                                      'osm_type': 'n',
#                                                      'toilets:wheelchair': 'no',
#                                                      'wheelchair': 'yes',
#                                                      'wheelchair:description': 'Accessible '
#                                                                                'via '
#                                                                                'Adelaide '
#                                                                                'Street '
#                                                                                'entrance'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.facilities'],
#                               'distance': 429,
#                               'district': 'Greater Brisbane',
#                               'facilities': {'toilets': False,
#                                              'wheelchair': True,
#                                              'wheelchair_details': {'description': 'Accessible '
#                                                                                    'via '
#                                                                                    'Adelaide '
#                                                                                    'Street '
#                                                                                    'entrance'}},
#                               'formatted': 'Post Office Square Pharmacy, Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'lat': -27.4675315,
#                               'lon': 153.0275308,
#                               'name': 'Post Office Square Pharmacy',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '513eb44588e1206340596f0af424b0773bc0f00103f9015615355c0000000092031b506f7374204f66666963652053717561726520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0268978, -27.47154169946197],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '108 Albert Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'brand': 'Priceline Pharmacy',
#                               'brand_details': {'wikidata': 'Q7242652',
#                                                 'wikipedia': 'en:Priceline '
#                                                              '(Australia)'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 1541754211,
#                                                      'osm_type': 'n',
#                                                      'toilets:wheelchair': 'no',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 441,
#                               'district': 'Brisbane City',
#                               'facilities': {'toilets': False,
#                                              'wheelchair': True},
#                               'formatted': 'Priceline Pharmacy, 108 Albert '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '108',
#                               'lat': -27.4715417,
#                               'lon': 153.0268978,
#                               'name': 'Priceline Pharmacy',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '51b36ac658dc20634059b1e3f1f4b6783bc0f00103f901634de55b0000000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Albert Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02900749999998,
#                                             -27.47025849946209],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Chemist Warehouse',
#                               'address_line2': 'Edward Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'brand': 'Chemist Warehouse',
#                               'brand_details': {'wikidata': 'Q48782120',
#                                                 'wikipedia': 'en:Chemist '
#                                                              'Warehouse'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:state': 'QLD',
#                                                      'addr:suburb': 'Brisbane',
#                                                      'amenity': 'pharmacy',
#                                                      'brand': 'Chemist '
#                                                               'Warehouse',
#                                                      'brand:wikidata': 'Q48782120',
#                                                      'brand:wikipedia': 'en:Chemist '
#                                                                         'Warehouse',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Chemist '
#                                                              'Warehouse',
#                                                      'osm_id': 8140167945,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 563,
#                               'district': 'Brisbane City',
#                               'formatted': 'Chemist Warehouse, Edward Street, '
#                                            'Brisbane City QLD 4000, Australia',
#                               'lat': -27.4702585,
#                               'lon': 153.0290075,
#                               'name': 'Chemist Warehouse',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '51d6fa22a1ed2063405910db6bdc62783bc0f00103f901091b31e5010000009203114368656d6973742057617265686f757365',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Edward Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0139689, -27.46541889946259],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Barracks Pharmacy',
#                               'address_line2': '61 Petrie Terrace, Petrie '
#                                                'Terrace QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Barracks '
#                                                              'Pharmacy',
#                                                      'opening_hours': 'Mo-We,Fr '
#                                                                       '08:00-17:00, '
#                                                                       'Th '
#                                                                       '08:00-19:30, '
#                                                                       'Sa '
#                                                                       '08:00-14:00, '
#                                                                       'Su '
#                                                                       '09:00-13:00',
#                                                      'osm_id': 5045884261,
#                                                      'osm_type': 'n',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 1021,
#                               'district': 'Petrie Terrace',
#                               'facilities': {'wheelchair': True},
#                               'formatted': 'Barracks Pharmacy, 61 Petrie '
#                                            'Terrace, Petrie Terrace QLD 4000, '
#                                            'Australia',
#                               'housenumber': '61',
#                               'lat': -27.4654189,
#                               'lon': 153.0139689,
#                               'name': 'Barracks Pharmacy',
#                               'opening_hours': 'Mo-We,Fr 08:00-17:00, Th '
#                                                '08:00-19:30, Sa 08:00-14:00, '
#                                                'Su 09:00-13:00',
#                               'place_id': '512815e86e7220634059d42168b125773bc0f00103f9016515c22c010000009203114261727261636b7320506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Petrie Terrace',
#                               'suburb': 'Petrie Terrace'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.03050839999997,
#                                             -27.46199189946293],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '365 Turbot Street, Spring Hill '
#                                                'QLD 4000, Australia',
#                               'brand': 'Priceline Pharmacy',
#                               'brand_details': {'wikidata': 'Q7242652',
#                                                 'wikipedia': 'en:Priceline '
#                                                              '(Australia)'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Spring Hill',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'name:en': 'Priceline '
#                                                                 'Pharmacy',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '08:00-19:00; '
#                                                                       'Sa '
#                                                                       '09:00-17:00; '
#                                                                       'Su '
#                                                                       '10:00-16:00',
#                                                      'osm_id': 4797796121,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1038,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Priceline Pharmacy, 365 Turbot '
#                                            'Street, Spring Hill QLD 4000, '
#                                            'Australia',
#                               'housenumber': '365',
#                               'lat': -27.4619919,
#                               'lon': 153.0305084,
#                               'name': 'Priceline Pharmacy',
#                               'name_international': {'en': 'Priceline '
#                                                            'Pharmacy'},
#                               'opening_hours': 'Mo-Fr 08:00-19:00; Sa '
#                                                '09:00-17:00; Su 10:00-16:00',
#                               'place_id': '511a88c0ecf920634059d035e31945763bc0f00103f901198ff81d0100000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Turbot Street',
#                               'suburb': 'Spring Hill'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02940839999997,
#                                             -27.477978099461303],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '2 George Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'brand': 'Priceline Pharmacy',
#                               'brand_details': {'wikidata': 'Q7242652'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 11182950824,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1157,
#                               'district': 'Brisbane City',
#                               'formatted': 'Priceline Pharmacy, 2 George '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '2',
#                               'lat': -27.4779781,
#                               'lon': 153.0294084,
#                               'name': 'Priceline Pharmacy',
#                               'neighbourhood': 'Golden Triangle',
#                               'place_id': '514887e2e9f020634059fa63d1c55c7a3bc0f00103f901a8498e9a0200000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'George Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.01198620000002,
#                                             -27.476914599461413],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'West End Discount Drug Stores',
#                               'address_line2': 'Mollison Street, West End QLD '
#                                                '4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'South Brisbane',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:postcode': 4101,
#                                                      'amenity': 'pharmacy',
#                                                      'name': 'West End '
#                                                              'Discount Drug '
#                                                              'Stores',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '08:00-20:00; '
#                                                                       'Sa '
#                                                                       '08:00-17:00; '
#                                                                       'Su '
#                                                                       '09:00-18:00',
#                                                      'osm_id': 506174931,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1439,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'West End Discount Drug Stores, '
#                                            'Mollison Street, West End QLD '
#                                            '4101, Australia',
#                               'lat': -27.4769146,
#                               'lon': 153.0119862,
#                               'name': 'West End Discount Drug Stores',
#                               'opening_hours': 'Mo-Fr 08:00-20:00; Sa '
#                                                '08:00-17:00; Su 09:00-18:00',
#                               'place_id': '511c20e2306220634059f5ab3f13177a3bc0f00103f901d39d2b1e0000000092031d5765737420456e6420446973636f756e7420447275672053746f726573',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Mollison Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02356549999996,
#                                             -27.482002499460897],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'TerryWhite Chemmart',
#                               'address_line2': 'Grey Street, South Brisbane '
#                                                'QLD 4101, Australia',
#                               'brand': 'TerryWhite Chemmart',
#                               'brand_details': {'wikidata': 'Q24089773',
#                                                 'wikipedia': 'en:Terry White '
#                                                              'Chemmart'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'South Brisbane',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'TerryWhite '
#                                                               'Chemmart',
#                                                      'brand:wikidata': 'Q24089773',
#                                                      'brand:wikipedia': 'en:Terry '
#                                                                         'White '
#                                                                         'Chemmart',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'TerryWhite '
#                                                              'Chemmart',
#                                                      'osm_id': 8685936422,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1444,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'TerryWhite Chemmart, Grey Street, '
#                                            'South Brisbane QLD 4101, Australia',
#                               'lat': -27.4820025,
#                               'lon': 153.0235655,
#                               'name': 'TerryWhite Chemmart',
#                               'neighbourhood': 'South Bank',
#                               'place_id': '510a7a6f0cc1206340595ac60b84647b3bc0f00103f90126dfb8050200000092031354657272795768697465204368656d6d617274',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Grey Street',
#                               'suburb': 'South Brisbane'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0115955, -27.477398299461374],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'TerryWhite Chemmart',
#                               'address_line2': '97 Boundary Street, West End '
#                                                'QLD 4101, Australia',
#                               'brand': 'TerryWhite Chemmart',
#                               'brand_details': {'wikidata': 'Q24089773',
#                                                 'wikipedia': 'en:Terry White '
#                                                              'Chemmart'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'West End',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'TerryWhite '
#                                                               'Chemmart',
#                                                      'brand:wikidata': 'Q24089773',
#                                                      'brand:wikipedia': 'en:Terry '
#                                                                         'White '
#                                                                         'Chemmart',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'TerryWhite '
#                                                              'Chemmart',
#                                                      'osm_id': 8924429400,
#                                                      'osm_type': 'n'},
# ...
#                               'lon': 153.0120306,
#                               'name': 'Andrew Thanos Pharmacy',
#                               'neighbourhood': 'Hill End',
#                               'place_id': '51a431ff8d622063405977450a5b0e7b3bc0f00103f90124f1436301000000920316416e64726577205468616e6f7320506861726d616379',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Boundary Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.01221809999998,
#                                             -27.480878899461022],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'TerryWhite Chemmart',
#                               'address_line2': '154 Boundary Street, West End '
#                                                'QLD 4101, Australia',
#                               'brand': 'TerryWhite Chemmart',
#                               'brand_details': {'wikidata': 'Q24089773',
#                                                 'wikipedia': 'en:Terry White '
#                                                              'Chemmart'},
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'West End',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'TerryWhite '
#                                                               'Chemmart',
#                                                      'brand:wikidata': 'Q24089773',
#                                                      'brand:wikipedia': 'en:Terry '
#                                                                         'White '
#                                                                         'Chemmart',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'TerryWhite '
#                                                              'Chemmart',
#                                                      'opening_hours': 'Mo-Sa '
#                                                                       '08:00-19:00; '
#                                                                       'Su '
#                                                                       '08:00-16:00',
#                                                      'osm_id': 2798568500,
#                                                      'osm_type': 'n',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 1728,
#                               'district': 'Greater Brisbane',
#                               'facilities': {'wheelchair': True},
#                               'formatted': 'TerryWhite Chemmart, 154 Boundary '
#                                            'Street, West End QLD 4101, '
#                                            'Australia',
#                               'housenumber': '154',
#                               'lat': -27.4808789,
#                               'lon': 153.0122181,
#                               'name': 'TerryWhite Chemmart',
#                               'neighbourhood': 'Hill End',
#                               'opening_hours': 'Mo-Sa 08:00-19:00; Su '
#                                                '08:00-16:00',
#                               'place_id': '516a7d3617642063405985852ae11a7b3bc0f00103f90134c4cea60000000092031354657272795768697465204368656d6d617274',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Boundary Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0198823, -27.484505299460643],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Gladstone Road Pharmacy',
#                               'address_line2': '30-34 Gladstone Road, Highgate '
#                                                'Hill QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Highgate Hill',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'name': 'Gladstone Road '
#                                                              'Pharmacy',
#                                                      'osm_id': 506174928,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1758,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Gladstone Road Pharmacy, 30-34 '
#                                            'Gladstone Road, Highgate Hill QLD '
#                                            '4101, Australia',
#                               'housenumber': '30-34',
#                               'lat': -27.4845053,
#                               'lon': 153.0198823,
#                               'name': 'Gladstone Road Pharmacy',
#                               'place_id': '519e8834e0a22063405912ec0f8a087c3bc0f00103f901d09d2b1e00000000920317476c616473746f6e6520526f616420506861726d616379',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Gladstone Road',
#                               'suburb': 'Highgate Hill'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.03557819999997,
#                                             -27.48085839946103],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Coffey',
#                               'address_line2': 'Main Street, Kangaroo Point '
#                                                'QLD 4169, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'Kangaroo Point',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Coffey',
#                                                      'osm_id': 6052259527,
#                                                      'osm_type': 'n',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.facilities'],
#                               'distance': 1778,
#                               'district': 'Greater Brisbane',
#                               'facilities': {'wheelchair': True},
#                               'formatted': 'Coffey, Main Street, Kangaroo '
#                                            'Point QLD 4169, Australia',
#                               'lat': -27.4808584,
#                               'lon': 153.0355782,
#                               'name': 'Coffey',
#                               'place_id': '516aaee474232163405929b13b89197b3bc0f00103f901c726be6801000000920306436f66666579',
#                               'postcode': '4169',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Main Street',
#                               'suburb': 'Kangaroo Point'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0277626, -27.4849501994606],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Mater Pharmacy',
#                               'address_line2': 'Raymond Terrace, South '
#                                                'Brisbane QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'South Brisbane',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'dispensing': 'yes',
#                                                      'drive_through': 'no',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Mater Pharmacy',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '08:00-18:00',
#                                                      'osm_id': 6649314305,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1820,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Mater Pharmacy, Raymond Terrace, '
#                                            'South Brisbane QLD 4101, Australia',
#                               'lat': -27.4849502,
#                               'lon': 153.0277626,
#                               'name': 'Mater Pharmacy',
#                               'opening_hours': 'Mo-Fr 08:00-18:00',
#                               'place_id': '51a961646ee32063405938df3eb2257c3bc0f00103f901017c548c0100000092030e4d6174657220506861726d616379',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Raymond Terrace',
#                               'suburb': 'South Brisbane'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.00472009999996,
#                                             -27.471522299461956],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Choice Chemist',
#                               'address_line2': '41 Douglas Street, Milton QLD '
#                                                '4064, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Milton',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'level': 2,
#                                                      'name': 'Choice Chemist',
#                                                      'osm_id': 5898069396,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1878,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Choice Chemist, 41 Douglas Street, '
#                                            'Milton QLD 4064, Australia',
#                               'housenumber': '41',
#                               'lat': -27.4715223,
#                               'lon': 153.0047201,
#                               'name': 'Choice Chemist',
#                               'place_id': '514764c4aa2620634059198677afb5783bc0f00103f90194658d5f0100000092030e43686f696365204368656d697374',
#                               'postcode': '4064',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Douglas Street',
#                               'suburb': 'Milton'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
print(response['features'][0]['properties']['address_line1'])
print(response['features'][0]['properties']['address_line2'])
# Out:
# Wizard Pharmacy
# Queen Street Mall, Brisbane City QLD 4000, Australia

# %% [markdown]
# ## 4. Find a pet shop within a 5km radius from the Sydney Opera House.

# %%
# Set the geographical coordinates for the Sydney Opera House

lon = 151.21512338473752
lat= -33.85719805

# Set the parameters for the type of place

categories = "pet.shop"

# Set the parameters for the type of search
radius = 5000
filter = f"circle:{lon},{lat},{radius}"
limit = 10
bias = f"proximity:{lon},{lat}"


# set up a parameters dictionary
params = {"categories": categories,
          "filter": filter,
          "limit": limit,
          "bias": bias,
          "apiKey": geoapify_key
         }

# Set base URL

base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
pet_response = requests.get(base_url, params = params).json()

# Print the json (pretty printed)
pprint(pet_response)
# Out:
# {'features': [{'geometry': {'coordinates': [151.22785899999997,
#                                             -33.87202299966735],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Pets Point',
#                               'address_line2': 'Elizabeth Bay Road, Elizabeth '
#                                                'Bay NSW 2011, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'commercial': {'type': 'pet'},
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:unit': 'Shop 4',
#                                                      'name': 'Pets Point',
#                                                      'osm_id': 10580904979,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 2023,
#                               'formatted': 'Pets Point, Elizabeth Bay Road, '
#                                            'Elizabeth Bay NSW 2011, Australia',
#                               'lat': -33.872023,
#                               'lon': 151.227859,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Pets Point',
#                               'place_id': '512c23f59e4ae76240592e771c739eef40c0f00103f90113ccab760200000092030a5065747320506f696e74',
#                               'postcode': '2011',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Elizabeth Bay Road',
#                               'suburb': 'Elizabeth Bay'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2098816, -33.88421939966951],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Petbarn',
#                               'address_line2': 'Foveaux Street, Surry Hills '
#                                                'NSW 2010, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'commercial': {'type': 'pet'},
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'name': 'Petbarn',
#                                                      'osm_id': 10948424184,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3036,
#                               'district': 'Strawberry Hills',
#                               'formatted': 'Petbarn, Foveaux Street, Surry '
#                                            'Hills NSW 2010, Australia',
#                               'lat': -33.8842194,
#                               'lon': 151.2098816,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Petbarn',
#                               'place_id': '5107019e59b7e6624059df08ee192ef140c0f00103f901f8b1938c020000009203075065746261726e',
#                               'postcode': '2010',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Foveaux Street',
#                               'suburb': 'Surry Hills'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.24449289999998,
#                                             -33.87744329966832],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Petbarn',
#                               'address_line2': 'New South Head Road, Double '
#                                                'Bay NSW 2028, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'commercial': {'type': 'pet'},
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'check_date': '2023-08-18',
#                                                      'name': 'Petbarn',
#                                                      'osm_id': 4925657661,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3525,
#                               'district': 'Eastern Suburbs',
#                               'formatted': 'Petbarn, New South Head Road, '
#                                            'Double Bay NSW 2028, Australia',
#                               'lat': -33.8774433,
#                               'lon': 151.2444929,
#                               'municipality': 'Woollahra Municipal Council',
#                               'name': 'Petbarn',
#                               'place_id': '515533c6e2d2e7624059bb15e20f50f040c0f00103f9013d929725010000009203075065746261726e',
#                               'postcode': '2028',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'New South Head Road',
#                               'suburb': 'Double Bay'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.200736, -33.82283299965868],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Petbarn',
#                               'address_line2': '160 Willoughby Road, Crows '
#                                                'Nest NSW 2065, Australia',
#                               'brand': 'Petbarn',
#                               'brand_details': {'wikidata': 'Q104746468'},
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'commercial': {'type': 'pet'},
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:country': 'AU',
#                                                      'addr:housenumber': 160,
#                                                      'addr:postcode': 2065,
#                                                      'addr:state': 'NSW',
#                                                      'addr:street': 'Willoughby '
#                                                                     'Road',
#                                                      'addr:suburb': 'Crows '
#                                                                     'Nest',
#                                                      'brand': 'Petbarn',
#                                                      'brand:wikidata': 'Q104746468',
#                                                      'name': 'Petbarn',
#                                                      'operator': 'Petbarn',
#                                                      'osm_id': 2625901404,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet',
#                                                      'website': 'https://www.petbarn.com.au/store-finder/crows-nest'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 4038,
#                               'district': 'Lower North Shore',
#                               'formatted': 'Petbarn, 160 Willoughby Road, '
#                                            'Crows Nest NSW 2065, Australia',
#                               'housenumber': '160',
#                               'lat': -33.822833,
#                               'lon': 151.200736,
#                               'municipality': 'North Sydney Council',
#                               'name': 'Petbarn',
#                               'neighbourhood': 'Crows Nest Junction',
#                               'operator': 'Petbarn',
#                               'place_id': '512864e76d6ce662405943cd7b9752e940c0f00103f9015c13849c000000009203075065746261726e',
#                               'postcode': '2065',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Willoughby Road',
#                               'suburb': 'Crows Nest',
#                               'website': 'https://www.petbarn.com.au/store-finder/crows-nest'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.1758722, -33.87607649966807],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Pet O',
#                               'address_line2': '1A The Crescent, Annandale NSW '
#                                                '2038, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'commercial': {'type': 'pet'},
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': '1A',
#                                                      'addr:street': 'The '
#                                                                     'Crescent',
#                                                      'name': 'Pet O',
#                                                      'osm_id': 7726482861,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet',
#                                                      'website': 'https://peto.com.au/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 4192,
#                               'district': 'Inner West',
#                               'formatted': 'Pet O, 1A The Crescent, Annandale '
#                                            'NSW 2038, Australia',
#                               'housenumber': '1A',
#                               'lat': -33.8760765,
#                               'lon': 151.1758722,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Pet O',
#                               'place_id': '51d168bcbea0e56240592c6f554623f040c0f00103f901adc588cc01000000920305506574204f',
#                               'postcode': '2038',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'The Crescent',
#                               'suburb': 'Annandale',
#                               'website': 'https://peto.com.au/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2436647, -33.890569499670654],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Dogue',
#                               'address_line2': 'Oxford Street, Bondi Junction '
#                                                'NSW 2022, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'commercial': {'type': 'pet'},
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'name': 'Dogue',
#                                                      'osm_id': 5902886018,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 4547,
#                               'district': 'Eastern Suburbs',
#                               'formatted': 'Dogue, Oxford Street, Bondi '
#                                            'Junction NSW 2022, Australia',
#                               'lat': -33.8905695,
#                               'lon': 151.2436647,
#                               'municipality': 'Waverley Council',
#                               'name': 'Dogue',
#                               'place_id': '5112b6e919cce762405945f36d2efef140c0f00103f90182e4d65f01000000920305446f677565',
#                               'postcode': '2022',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Oxford Street',
#                               'suburb': 'Bondi Junction'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
print(pet_response["features"][0]["properties"]["name"])
print(pet_response["features"][0]["properties"]["address_line2"])
# Out:
# Pets Point
# Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia

# %% [markdown]
# ## 5. Find the nearest dentist to your house.
#
# > **Hint:** Use Geoapify Geocode to find your latitude and Geoapify Places to find the dentist.

# %%
# Geoapify Geocode to find latitude and longitude
my_address = "801 Park Street, Salt Lake City, Utah"


params = {"text": my_address,
          "apiKey": geoapify_key
         }
# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search?"

# %%
# Run request
address_response = requests.get(base_url, params = params).json()

# Print the json (pretty printed)
pprint(address_response)
# Out:
# {'features': [{'bbox': [-111.8751588, 40.7516793, -111.8749875, 40.7517685],
#                'geometry': {'coordinates': [-111.87507333797683,
#                                             40.751716849999994],
#                             'type': 'Point'},
#                'properties': {'address_line1': '801 Park Street',
#                               'address_line2': 'Salt Lake City, UT 84102, '
#                                                'United States of America',
#                               'category': 'building.residential',
#                               'city': 'Salt Lake City',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database License',
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'district': 'Central City / Liberty-Wells',
#                               'formatted': '801 Park Street, Salt Lake City, '
#                                            'UT 84102, United States of America',
#                               'housenumber': '801',
#                               'lat': 40.751716849999994,
#                               'lon': -111.87507333797683,
#                               'place_id': '51920d9a3301f85bc059124dfb4138604440f00102f901680a092300000000c00203',
#                               'plus_code': '85GCQ42F+MX',
#                               'plus_code_short': 'Q42F+MX Salt Lake City, Salt '
#                                                  'Lake County, United States',
#                               'postcode': '84102',
#                               'rank': {'confidence': 1,
#                                        'confidence_city_level': 1,
#                                        'confidence_street_level': 1,
#                                        'importance': 0.31001,
#                                        'match_type': 'full_match',
#                                        'popularity': 3.6481227276296027},
#                               'result_type': 'building',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': 'Park Street',
#                               'timezone': {'abbreviation_DST': 'MDT',
#                                            'abbreviation_STD': 'MST',
#                                            'name': 'America/Denver',
#                                            'offset_DST': '-06:00',
#                                            'offset_DST_seconds': -21600,
#                                            'offset_STD': '-07:00',
#                                            'offset_STD_seconds': -25200}},
#                'type': 'Feature'},
#               {'bbox': [-111.875279, 40.751785, -111.875179, 40.751885],
#                'geometry': {'coordinates': [-111.875229, 40.751835],
#                             'type': 'Point'},
#                'properties': {'address_line1': '801 Park Street',
#                               'address_line2': 'Salt Lake City, UT 84102, '
#                                                'United States of America',
#                               'city': 'Salt Lake City',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database License',
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'district': 'Central City / Liberty-Wells',
#                               'formatted': '801 Park Street, Salt Lake City, '
#                                            'UT 84102, United States of America',
#                               'housenumber': '801',
#                               'lat': 40.751835,
#                               'lon': -111.875229,
#                               'place_id': '51b1e07ec003f85bc0597c7e18213c604440f00102f9014ab59a0000000000c00203',
#                               'plus_code': '85GCQ42F+PW',
#                               'plus_code_short': 'Q42F+PW Salt Lake City, Salt '
#                                                  'Lake County, United States',
#                               'postcode': '84102',
#                               'rank': {'confidence': 1,
#                                        'confidence_city_level': 1,
#                                        'confidence_street_level': 1,
#                                        'importance': -0.8399999999999999,
#                                        'match_type': 'full_match',
#                                        'popularity': 3.6481227276296027},
#                               'result_type': 'building',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': 'Park Street',
#                               'timezone': {'abbreviation_DST': 'MDT',
#                                            'abbreviation_STD': 'MST',
#                                            'name': 'America/Denver',
#                                            'offset_DST': '-06:00',
#                                            'offset_DST_seconds': -21600,
#                                            'offset_STD': '-07:00',
#                                            'offset_STD_seconds': -25200}},
#                'type': 'Feature'}],
#  'query': {'parsed': {'city': 'salt lake city',
#                       'expected_type': 'building',
#                       'housenumber': '801',
#                       'state': 'utah',
#                       'street': 'park street'},
#            'text': '801 Park Street, Salt Lake City, Utah'},
#  'type': 'FeatureCollection'}

# %%
# Extract lat/lon

lat = address_response['features'][0]['properties']['lat']
lon = address_response['features'][0]['properties']['lon']
# Print results
print(f' {my_address}: {lon},{lat}')
# Out:
#  801 Park Street, Salt Lake City, Utah: -111.87507333797683,40.751716849999994

# %%
# Set the geographical coordinates for my home

# Set the parameters for the type of place
categories = "healthcare.dentist"

# Set the parameters for the type of search
radius = 5000
filter = f"circle:{lon},{lat},{radius}"
limit = 1
bias = f"proximity:{lon},{lat}"
# set up a parameters dictionary

params = {"categories": categories,
          "limit": limit,
          "bias": bias,
          "apiKey": geoapify_key,
          "filter": filter

         }

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request

dentist_response = requests.get(base_url, params = params).json()
# Print the json (pretty printed)
pprint(dentist_response)
# Out:
# {'features': [{'geometry': {'coordinates': [-111.87075079999998,
#                                             40.75001680036326],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Graham Orthodontics',
#                               'address_line2': '705 900 South, Salt Lake City, '
#                                                'UT 84105, United States of '
#                                                'America',
#                               'categories': ['healthcare',
#                                              'healthcare.dentist',
#                                              'healthcare.dentist.orthodontics'],
#                               'city': 'Salt Lake City',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'dentist',
#                                                      'healthcare': 'dentist',
#                                                      'healthcare:speciality': 'orthodontics',
#                                                      'name': 'Graham '
#                                                              'Orthodontics',
#                                                      'operator': 'John Graham, '
#                                                                  'DDS, MD',
#                                                      'osm_id': 10290220037,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 411,
#                               'district': '9th & 9th',
#                               'formatted': 'Graham Orthodontics, 705 900 '
#                                            'South, Salt Lake City, UT 84105, '
#                                            'United States of America',
#                               'housenumber': '705',
#                               'lat': 40.7500168,
#                               'lon': -111.8707508,
#                               'name': 'Graham Orthodontics',
#                               'operator': 'John Graham, DDS, MD',
#                               'place_id': '51cf3d9061baf75bc0596181ee8c00604440f00103f901054c58650200000092031347726168616d204f7274686f646f6e74696373',
#                               'postcode': '84105',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': '900 South'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
print(dentist_response["features"][0]["properties"]["name"])
print(dentist_response["features"][0]["properties"]["address_line2"])
# Out:
# Graham Orthodontics
# 705 900 South, Salt Lake City, UT 84105, United States of America

# %% [markdown]
# ## 6. Bonus: Find the names and addresses of the five nearest restaurants with internet access in your home city area.
#
# > **Hint:** Read about the `proximity` bias to order the results from the nearest to the farest place. Also, read about the `conditions` to identify places that provide internet access.

# %%
# Set the geographical coordinates for my home


# Set the parameters for the type of place
categories = "catering.restaurant"
conditions = "internet_access"
# Set the parameters for the type of search

radius = 5000
filter = f"circle:{lon},{lat},{radius}"
limit = 5
bias = f"proximity:{lon},{lat}"
# set up a parameters dictionary
params = {"categories": categories,
          "conditions": conditions,
          "limit": limit,
          "bias": bias,
          "apiKey": geoapify_key,
          "filter": filter

         }

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
rest_response = requests.get(base_url, params = params).json()

# Print the json (pretty printed)
pprint(rest_response)
# Out:
# {'features': [{'geometry': {'coordinates': [-111.888554, 40.75462210036381],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Mark of the Beastro',
#                               'address_line2': '666 State Street, Salt Lake '
#                                                'City, UT 84111, United States '
#                                                'of America',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'internet_access',
#                                              'vegan',
#                                              'vegan.only'],
#                               'catering': {'diet': {'gluten_free': False,
#                                                     'vegan': True}},
#                               'city': 'Salt Lake City',
#                               'contact': {'phone': '+1 385-202-7386'},
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Salt Lake '
#                                                                   'City',
#                                                      'addr:housenumber': 666,
#                                                      'addr:street': 'State '
#                                                                     'Street',
#                                                      'amenity': 'restaurant',
#                                                      'contact:facebook': 'https://www.facebook.com/Markofthebeastro/',
#                                                      'contact:instagram': 'https://www.instagram.com/markofthebeastro/',
#                                                      'contact:phone': '+1 '
#                                                                       '385-202-7386',
#                                                      'contact:website': 'https://markofthebeastro.com',
#                                                      'description': 'All-vegan '
#                                                                     'comfort '
#                                                                     'food with '
#                                                                     'a punk '
#                                                                     'vibe. '
#                                                                     'Featuring '
#                                                                     'chicken '
#                                                                     'and '
#                                                                     'waffles, '
#                                                                     'French '
#                                                                     'toast, '
#                                                                     'burgers, '
#                                                                     'and other '
#                                                                     'diner '
#                                                                     'classics. '
#                                                                     '(Source:  '
#                                                                     'UARC '
#                                                                     'directory)',
#                                                      'diet:gluten_free': 'no',
#                                                      'diet:vegan': 'only',
#                                                      'internet_access': 'wlan',
#                                                      'name': 'Mark of the '
#                                                              'Beastro',
#                                                      'opening_hours': 'We-Fr '
#                                                                       '18:00-23:00; '
#                                                                       'Sa '
#                                                                       '11:00-23:00; '
#                                                                       'Su '
#                                                                       '11:00-21:00',
#                                                      'osm_id': 9278976617,
#                                                      'osm_type': 'n',
#                                                      'takeaway': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'description': 'All-vegan comfort food with a '
#                                              'punk vibe. Featuring chicken and '
#                                              'waffles, French toast, burgers, '
#                                              'and other diner classics. '
#                                              '(Source:  UARC directory)',
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 1183,
#                               'district': 'Central City',
#                               'facilities': {'internet_access': True,
#                                              'takeaway': True},
#                               'formatted': 'Mark of the Beastro, 666 State '
#                                            'Street, Salt Lake City, UT 84111, '
#                                            'United States of America',
#                               'housenumber': '666',
#                               'lat': 40.7546221,
#                               'lon': -111.888554,
#                               'name': 'Mark of the Beastro',
#                               'opening_hours': 'We-Fr 18:00-23:00; Sa '
#                                                '11:00-23:00; Su 11:00-21:00',
#                               'place_id': '51b8ae9811def85bc05961f3fc7497604440f00103f90169f21129020000009203134d61726b206f6620746865204265617374726f',
#                               'postcode': '84111',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': 'State Street',
#                               'website': 'https://markofthebeastro.com'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-111.88370099999999,
#                                             40.76087710036456],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Vietopia Deli',
#                               'address_line2': '249 E 400 South, Salt Lake '
#                                                'City, UT 84111, United States '
#                                                'of America',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.vietnamese',
#                                              'internet_access',
#                                              'vegetarian'],
#                               'catering': {'cuisine': 'vietnamese',
#                                            'diet': {'vegetarian': True}},
#                               'city': 'Salt Lake City',
#                               'contact': {'phone': '385-227-8377'},
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Salt Lake '
#                                                                   'City',
#                                                      'addr:country': 'US',
#                                                      'addr:housenumber': '249 '
#                                                                          'E',
#                                                      'addr:postcode': 84111,
#                                                      'addr:state': 'UT',
#                                                      'addr:street': '400 South',
#                                                      'addr:street:prefix': 'East',
#                                                      'amenity': 'restaurant',
#                                                      'check_date:opening_hours': '2023-03-25',
#                                                      'cuisine': 'vietnamese',
#                                                      'diet:vegetarian': 'limited',
#                                                      'internet_access': 'yes',
#                                                      'internet_access:ssid': 'VietopiaDeliGuest2.4G',
#                                                      'level': 0,
#                                                      'name': 'Vietopia Deli',
#                                                      'opening_hours': 'Mo-Sa '
#                                                                       '11:00-21:00; '
#                                                                       'Su off',
#                                                      'osm_id': 9335676372,
#                                                      'osm_type': 'n',
#                                                      'payment:cash': 'yes',
#                                                      'payment:credit_cards': 'yes',
#                                                      'phone': '385-227-8377'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact',
#                                           'details.facilities',
#                                           'details.payment'],
#                               'distance': 1251,
#                               'district': 'Central City',
#                               'facilities': {'internet_access': True,
#                                              'internet_access_details': {'ssid': 'VietopiaDeliGuest2.4G'}},
#                               'formatted': 'Vietopia Deli, 249 E 400 South, '
#                                            'Salt Lake City, UT 84111, United '
#                                            'States of America',
#                               'housenumber': '249 E',
#                               'lat': 40.7608771,
#                               'lon': -111.883701,
#                               'name': 'Vietopia Deli',
#                               'opening_hours': 'Mo-Sa 11:00-21:00; Su off',
#                               'payment_options': {'cash': True,
#                                                   'credit_cards': True},
#                               'place_id': '51519ca38e8ef85bc059a92bbb6b64614440f00103f901d41d732c0200000092030d566965746f7069612044656c69',
#                               'postcode': '84111',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': '400 South'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-111.9068436, 40.753644500363706],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Bok Bok',
#                               'address_line2': 'Woodbine Street, Salt Lake '
#                                                'City, UT 84101, United States '
#                                                'of America',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.chicken',
#                                              'internet_access',
#                                              'internet_access.free',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'catering': {'cuisine': 'chicken'},
#                               'city': 'Salt Lake City',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'restaurant',
#                                                      'check_date': '2023-11-15',
#                                                      'cuisine': 'chicken',
#                                                      'internet_access': 'wlan',
#                                                      'internet_access:fee': 'no',
#                                                      'name': 'Bok Bok',
#                                                      'opening_hours': 'Tu-Th '
#                                                                       '11:30-14:30; '
#                                                                       'Fr-Sa '
#                                                                       '17:30-21:30',
#                                                      'osm_id': 11353308743,
#                                                      'osm_type': 'n',
#                                                      'payment:cash': 'yes',
#                                                      'payment:mastercard': 'yes',
#                                                      'payment:visa': 'yes',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.facilities',
#                                           'details.payment'],
#                               'distance': 2691,
#                               'district': 'Granary District',
#                               'facilities': {'internet_access': True,
#                                              'wheelchair': True},
#                               'formatted': 'Bok Bok, Woodbine Street, Salt '
#                                            'Lake City, UT 84101, United States '
#                                            'of America',
#                               'lat': 40.7536445,
#                               'lon': -111.9068436,
#                               'name': 'Bok Bok',
#                               'opening_hours': 'Tu-Th 11:30-14:30; Fr-Sa '
#                                                '17:30-21:30',
#                               'payment_options': {'cash': True,
#                                                   'mastercard': True,
#                                                   'visa': True},
#                               'place_id': '519025bdb909fa5bc059aaef486c77604440f00103f90147beb5a402000000920307426f6b20426f6b',
#                               'postcode': '84101',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': 'Woodbine Street'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-111.89240346661893,
#                                             40.775390500366285],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Arlo',
#                               'address_line2': '271, Salt Lake City, UT 84150, '
#                                                'United States of America',
#                               'categories': ['building',
#                                              'building.catering',
#                                              'catering',
#                                              'catering.restaurant',
#                                              'internet_access',
#                                              'internet_access.free',
#                                              'vegetarian'],
#                               'catering': {'diet': {'vegetarian': True}},
#                               'city': 'Salt Lake City',
#                               'contact': {'phone': '+1-385-266-8845'},
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Salt Lake '
#                                                                   'City',
#                                                      'addr:country': 'US',
#                                                      'addr:housenumber': 271,
#                                                      'addr:place': 'Marmalade',
#                                                      'addr:state': 'UT',
#                                                      'addr:street': 'West '
#                                                                     'Center '
#                                                                     'Street;Center '
#                                                                     'Street',
#                                                      'amenity': 'restaurant',
#                                                      'building': 'yes',
#                                                      'diet:vegetarian': 'yes',
#                                                      'internet_access': 'wlan',
#                                                      'internet_access:fee': 'no',
#                                                      'name': 'Arlo',
#                                                      'opening_hours:covid19': 'We-Su '
#                                                                               '17:30-21:30',
#                                                      'osm_id': 453285490,
#                                                      'osm_type': 'w',
#                                                      'outdoor_seating': 'yes',
#                                                      'phone': '+1-385-266-8845',
#                                                      'smoking': 'no',
#                                                      'website': 'https://www.arlorestaurant.com'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 3001,
#                               'district': 'Marmalade District',
#                               'facilities': {'internet_access': True,
#                                              'outdoor_seating': True,
#                                              'smoking': False},
#                               'formatted': 'Arlo, 271, Salt Lake City, UT '
#                                            '84150, United States of America',
#                               'housenumber': '271',
#                               'lat': 40.7753905,
#                               'lon': -111.89240346661893,
#                               'name': 'Arlo',
#                               'opening_hours_covid19': 'We-Su 17:30-21:30',
#                               'place_id': '51c8fd6d231df95bc059e459f4fe3f634440f00102f9017296041b0000000092030441726c6f',
#                               'postcode': '84150',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'website': 'https://www.arlorestaurant.com'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-111.90010395, 40.725082950360296],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'IHOP',
#                               'address_line2': '307 W 2100 South, Salt Lake '
#                                                'City, UT 84115, United States '
#                                                'of America',
#                               'brand': 'IHOP',
#                               'brand_details': {'wikidata': 'Q1185675'},
#                               'building': {'levels': 1, 'type': 'retail'},
#                               'categories': ['building',
#                                              'building.catering',
#                                              'building.commercial',
#                                              'catering',
#                                              'catering.restaurant',
#                                              'internet_access',
#                                              'internet_access.free',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'catering': {'cuisine': 'breakfast;pancake'},
#                               'city': 'Salt Lake City',
#                               'contact': {'phone': '+1-801-461-4466'},
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Salt Lake County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Salt Lake '
#                                                                   'City',
#                                                      'addr:country': 'US',
#                                                      'addr:housenumber': '307 '
#                                                                          'W',
#                                                      'addr:postcode': 84115,
#                                                      'addr:state': 'UT',
#                                                      'addr:street': '2100 '
#                                                                     'South',
#                                                      'amenity': 'restaurant',
#                                                      'brand': 'IHOP',
#                                                      'brand:wikidata': 'Q1185675',
#                                                      'building': 'retail',
#                                                      'building:levels': 1,
#                                                      'cuisine': 'breakfast;pancake',
#                                                      'delivery': 'yes',
#                                                      'internet_access': 'wlan',
#                                                      'internet_access:fee': 'no',
#                                                      'name': 'IHOP',
#                                                      'opening_hours': 'Mo '
#                                                                       '06:00-24:00; '
#                                                                       'Tu-Su '
#                                                                       '00:00-24:00',
#                                                      'osm_id': 471181273,
#                                                      'osm_type': 'w',
#                                                      'outdoor_seating': 'no',
#                                                      'phone': '+1-801-461-4466',
#                                                      'smoking': 'outside',
#                                                      'takeaway': 'yes',
#                                                      'website': 'https://restaurants.ihop.com/en-us/ut/salt-lake-city/breakfast-307-west-2100-s-1774',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.building',
#                                           'details.catering',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 3621,
#                               'facilities': {'delivery': True,
#                                              'internet_access': True,
#                                              'outdoor_seating': False,
#                                              'smoking': True,
#                                              'takeaway': True,
#                                              'wheelchair': True},
#                               'formatted': 'IHOP, 307 W 2100 South, Salt Lake '
#                                            'City, UT 84115, United States of '
#                                            'America',
#                               'housenumber': '307 W',
#                               'lat': 40.72508295,
#                               'lon': -111.90010395,
#                               'name': 'IHOP',
#                               'opening_hours': 'Mo 06:00-24:00; Tu-Su '
#                                                '00:00-24:00',
#                               'place_id': '510710994d9bf95bc059a357a384cf5c4440f00102f901d9a7151c0000000092030449484f50',
#                               'postcode': '84115',
#                               'state': 'Utah',
#                               'state_code': 'UT',
#                               'street': '2100 South',
#                               'website': 'https://restaurants.ihop.com/en-us/ut/salt-lake-city/breakfast-307-west-2100-s-1774'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
counter = 0

for place in rest_response["features"]:
    print(f"Restaurant {counter+1}:")
    print(place["properties"]["name"])
    print(place["properties"]["address_line2"])
    print("-"*20)
    counter = counter + 1
    if counter == 5:
        break
# Out:
# Restaurant 1:
# Mark of the Beastro
# 666 State Street, Salt Lake City, UT 84111, United States of America
# --------------------
# Restaurant 2:
# Vietopia Deli
# 249 E 400 South, Salt Lake City, UT 84111, United States of America
# --------------------
# Restaurant 3:
# Bok Bok
# Woodbine Street, Salt Lake City, UT 84101, United States of America
# --------------------
# Restaurant 4:
# Arlo
# 271, Salt Lake City, UT 84150, United States of America
# --------------------
# Restaurant 5:
# IHOP
# 307 W 2100 South, Salt Lake City, UT 84115, United States of America
# --------------------
