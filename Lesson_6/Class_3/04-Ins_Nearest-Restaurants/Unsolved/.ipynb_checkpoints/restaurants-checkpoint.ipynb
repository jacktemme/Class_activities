# %% [markdown]
# # Nearest Restaurants in Madrid

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
# Import the API key
from config import geoapify_key

# %%
# Load the restaurant ethnicities into a DataFrame
types_df = pd.read_csv("../Resources/ethnicities.csv")

# Display sample data
types_df.head()
# Out:
#   ethnicity
# 0   italian
# 1   chinese
# 2   mexican
# 3  japanese
# 4  american

# %%
# Set up additional columns to hold information
types_df["name"] = ""
types_df["address"] = ""
types_df["distance"] = ""

# Display sample data
types_df.head()
# Out:
#   ethnicity name address distance
# 0   italian
# 1   chinese
# 2   mexican
# 3  japanese
# 4  american

# %% [markdown]
# Find the closest restaurant of each type to the Plaza Mayor in Madrid, Spain
#
# * Latitude: 40.415392
#
# * Longitude: -3.7073743182788528

# %%
# Set the geographical coordinates
latitude = 40.415392
longitude = -3.7073743182788528

# Set the parameters for the type of search
limit = 20
radius = 1000
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"

# set up a parameters dictionary
params = {
    "filter":filters,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key,
    "categories": f"catering.restaurant.italian"
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
response = response= requests.get(base_url, params = params).json()
pprint(response)
# Out:
# {'features': [{'geometry': {'coordinates': [-3.7080592999999995,
#                                             40.41495210032194],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'La Fojetta',
#                               'address_line2': 'Calle de la Escalerilla de '
#                                                'Piedra, 2, 28005 Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '+34 910347514'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 2,
#                                                      'addr:postcode': 28005,
#                                                      'addr:street': 'Calle de '
#                                                                     'la '
#                                                                     'Escalerilla '
#                                                                     'de Piedra',
#                                                      'amenity': 'restaurant',
#                                                      'contact:phone': '+34 '
#                                                                       '910347514',
#                                                      'contact:website': 'http://www.lafojetta.com/it-it/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'La Fojetta',
#                                                      'osm_id': 4709865265,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 76,
#                               'district': 'Centro',
#                               'formatted': 'La Fojetta, Calle de la '
#                                            'Escalerilla de Piedra, 2, 28005 '
#                                            'Madrid, Spain',
#                               'housenumber': '2',
#                               'lat': 40.4149521,
#                               'lon': -3.7080593,
#                               'name': 'La Fojetta',
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'place_id': '517a0789fe1aaa0dc059062582261d354440f00103f90131d7ba180100000092030a4c6120466f6a65747461',
#                               'postcode': '28005',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de la Escalerilla de Piedra',
#                               'suburb': 'Sol',
#                               'website': 'http://www.lafojetta.com/it-it/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7070659999999998,
#                                             40.416551000322144],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Trattoria Malatesta',
#                               'address_line2': 'Calle de Coloreros, 5, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': 5,
#                                                      'addr:street': 'Calle de '
#                                                                     'Coloreros',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Trattoria '
#                                                              'Malatesta',
#                                                      'name:es': 'Trattoria '
#                                                                 'Malatesta',
#                                                      'osm_id': 4935197121,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.catering'],
#                               'distance': 131,
#                               'district': 'Centro',
#                               'formatted': 'Trattoria Malatesta, Calle de '
#                                            'Coloreros, 5, 28013 Madrid, Spain',
#                               'housenumber': '5',
#                               'lat': 40.416551,
#                               'lon': -3.707066,
#                               'name': 'Trattoria Malatesta',
#                               'name_international': {'es': 'Trattoria '
#                                                            'Malatesta'},
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'place_id': '5185e8103812a80dc059f6bf0d8b51354440f00103f901c12129260100000092031354726174746f726961204d616c617465737461',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Coloreros',
#                               'suburb': 'Sol'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7070404, 40.41668900032216],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Malatesta',
#                               'address_line2': 'Calle de Coloreros, 5, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '(+34) 91 365 9097'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 5,
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Calle de '
#                                                                     'Coloreros',
#                                                      'amenity': 'restaurant',
#                                                      'contact:phone': '(+34) '
#                                                                       '91 365 '
#                                                                       '9097',
#                                                      'contact:website': 'http://www.trattoriamalatesta.com/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Malatesta',
#                                                      'name:ru': 'Malatesta '
#                                                                 'nomer1',
#                                                      'osm_id': 3502726880,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 147,
#                               'district': 'Centro',
#                               'formatted': 'Malatesta, Calle de Coloreros, 5, '
#                                            '28013 Madrid, Spain',
#                               'housenumber': '5',
#                               'lat': 40.416689,
#                               'lon': -3.7070404,
#                               'name': 'Malatesta',
#                               'name_international': {'ru': 'Malatesta nomer1'},
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'place_id': '51279b17cc04a80dc059497eae1056354440f00103f901e05ec7d0000000009203094d616c617465737461',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Coloreros',
#                               'suburb': 'Sol',
#                               'website': 'http://www.trattoriamalatesta.com/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7083973, 40.41676910032216],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Impasta',
#                               'address_line2': 'Calle de las Hileras, 2, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '+34 918 663 878'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 2,
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Calle de '
#                                                                     'las '
#                                                                     'Hileras',
#                                                      'amenity': 'restaurant',
#                                                      'contact:phone': '+34 918 '
#                                                                       '663 878',
#                                                      'contact:website': 'http://impasta-es.bar/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Impasta',
#                                                      'old_name': 'Yerbabuena',
#                                                      'osm_id': 4614116448,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 176,
#                               'district': 'Centro',
#                               'formatted': 'Impasta, Calle de las Hileras, 2, '
#                                            '28013 Madrid, Spain',
#                               'housenumber': '2',
#                               'lat': 40.4167691,
#                               'lon': -3.7083973,
#                               'name': 'Impasta',
#                               'name_other': {'old_name': 'Yerbabuena'},
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'old_name': 'Yerbabuena',
#                               'place_id': '51fd982034ccaa0dc059fbee9bb058354440f00103f90160d4051301000000920307496d7061737461',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de las Hileras',
#                               'suburb': 'Sol',
#                               'website': 'http://impasta-es.bar/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.707585433683472,
#                                             40.41366100032177],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Bella Vista',
#                               'address_line2': 'Calle de Toledo, 28, 28005 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 28,
#                                                      'addr:postcode': 28005,
#                                                      'addr:street': 'Calle de '
#                                                                     'Toledo',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Bella Vista',
#                                                      'name:2014': 'Los Nobles '
#                                                                   'de Castilla',
#                                                      'name:2019': 'Cubiertos '
#                                                                   'de Gloria',
#                                                      'osm_id': 692427558,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 188,
#                               'district': 'Centro',
#                               'formatted': 'Bella Vista, Calle de Toledo, 28, '
#                                            '28005 Madrid, Spain',
#                               'housenumber': '28',
#                               'lat': 40.413661000000005,
#                               'lon': -3.707585433683474,
#                               'name': 'Bella Vista',
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'place_id': '51365f468d22a90dc0599e01fad7f2344440f00102f901269b45290000000092030b42656c6c61205669737461',
#                               'postcode': '28005',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Toledo',
#                               'suburb': 'Sol'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.708480199999999,
#                                             40.41289070032168],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'La Tagliatella',
#                               'address_line2': 'Calle de la Cava Baja, 11, '
#                                                '28005 Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '+34 913546790'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 11,
#                                                      'addr:postcode': 28005,
#                                                      'addr:street': 'Calle de '
#                                                                     'la Cava '
#                                                                     'Baja',
#                                                      'amenity': 'restaurant',
#                                                      'contact:phone': '+34 '
#                                                                       '913546790',
#                                                      'contact:website': 'http://www.latagliatella.es/restaurantes/la-tagliatella-cava-baja/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'La Tagliatella',
#                                                      'old_name': 'El Schotis',
#                                                      'osm_id': 3682315227,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 293,
#                               'district': 'Centro',
#                               'formatted': 'La Tagliatella, Calle de la Cava '
#                                            'Baja, 11, 28005 Madrid, Spain',
#                               'housenumber': '11',
#                               'lat': 40.4128907,
#                               'lon': -3.7084802,
#                               'name': 'La Tagliatella',
#                               'name_other': {'old_name': 'El Schotis'},
#                               'neighbourhood': 'Barrio de la Latina',
#                               'old_name': 'El Schotis',
#                               'place_id': '5185e8c6aaf7aa0dc059225a3b9ad9344440f00103f901dbab7bdb0000000092030e4c61205461676c696174656c6c61',
#                               'postcode': '28005',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de la Cava Baja',
#                               'suburb': 'Palacio',
#                               'website': 'http://www.latagliatella.es/restaurantes/la-tagliatella-cava-baja/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7083295, 40.417982200322314],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Anema e Core',
#                               'address_line2': 'Calle de los Donados, 2, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'email': 'info@anemaecore.net',
#                                           'phone': '+34 91 542 22 53'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 2,
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Calle de '
#                                                                     'los '
#                                                                     'Donados',
#                                                      'amenity': 'restaurant',
#                                                      'contact:email': 'info@anemaecore.net',
#                                                      'contact:phone': '+34 91 '
#                                                                       '542 22 '
#                                                                       '53',
#                                                      'contact:website': 'http://www.anemaecore.net/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Anema e Core',
#                                                      'opening_hours': 'Mo-Su '
#                                                                       '13:30-16:00, '
#                                                                       '20:30-00:00',
#                                                      'osm_id': 3715230150,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 299,
#                               'district': 'Centro',
#                               'formatted': 'Anema e Core, Calle de los '
#                                            'Donados, 2, 28013 Madrid, Spain',
#                               'housenumber': '2',
#                               'lat': 40.4179822,
#                               'lon': -3.7083295,
#                               'name': 'Anema e Core',
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'opening_hours': 'Mo-Su 13:30-16:00, 20:30-00:00',
#                               'place_id': '5115562aa8a8aa0dc059e458d47080354440f00103f901c6e971dd0000000092030c416e656d61206520436f7265',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de los Donados',
#                               'suburb': 'Sol',
#                               'website': 'http://www.anemaecore.net/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7095419, 40.41773110032229],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Terraza Cafe del Real',
#                               'address_line2': 'Plaza de Isabel II, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'layer': -1,
#                                                      'name': 'Terraza Cafe del '
#                                                              'Real',
#                                                      'osm_id': 1556708447,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 318,
#                               'district': 'Centro',
#                               'formatted': 'Terraza Cafe del Real, Plaza de '
#                                            'Isabel II, 28013 Madrid, Spain',
#                               'lat': 40.4177311,
#                               'lon': -3.7095419,
#                               'name': 'Terraza Cafe del Real',
#                               'neighbourhood': 'Barrio de la Latina',
#                               'place_id': '513522bd4d24ad0dc0590334733678354440f00103f9015f7cc95c0000000092031554657272617a6120436166652064656c205265616c',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Plaza de Isabel II',
#                               'suburb': 'Palacio'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7037744, 40.414069000321824],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'La Tagliatella',
#                               'address_line2': 'Calle de Atocha, 16, 28012 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'La Tagliatella',
#                                                      'osm_id': 1572572823,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 339,
#                               'district': 'Centro',
#                               'formatted': 'La Tagliatella, Calle de Atocha, '
#                                            '16, 28012 Madrid, Spain',
#                               'housenumber': '16',
#                               'lat': 40.414069,
#                               'lon': -3.7037744,
#                               'name': 'La Tagliatella',
#                               'neighbourhood': 'Barrio de las Letras',
#                               'place_id': '519f18fe7854a10dc059b755873600354440f00103f901978ebb5d0000000092030e4c61205461676c696174656c6c61',
#                               'postcode': '28012',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Atocha'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7089635999999992,
#                                             40.41250010032163],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Emma y Julia',
#                               'address_line2': 'Calle de la Cava Baja, 19, '
#                                                '28005 Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '+34 913 66 10 23'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 19,
#                                                      'addr:postcode': 28005,
#                                                      'addr:street': 'Calle de '
#                                                                     'la Cava '
#                                                                     'Baja',
#                                                      'amenity': 'restaurant',
#                                                      'contact:phone': '+34 913 '
#                                                                       '66 10 '
#                                                                       '23',
#                                                      'contact:website': 'http://emmayjulia.com/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Emma y Julia',
#                                                      'osm_id': 4405701885,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 348,
#                               'district': 'Centro',
#                               'formatted': 'Emma y Julia, Calle de la Cava '
#                                            'Baja, 19, 28005 Madrid, Spain',
#                               'housenumber': '19',
#                               'lat': 40.4125001,
#                               'lon': -3.7089636,
#                               'name': 'Emma y Julia',
#                               'neighbourhood': 'Barrio de la Latina',
#                               'place_id': '51756fa01bf5ab0dc059333da4cdcc344440f00103f901fdac99060100000092030c456d6d612079204a756c6961',
#                               'postcode': '28005',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de la Cava Baja',
#                               'suburb': 'Palacio',
#                               'website': 'http://emmayjulia.com/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7086522999999993,
#                                             40.41875770032242],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Ouh Babbo!',
#                               'address_line2': 'Calle de Caños del Peral, '
#                                                '28013 Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Calle de '
#                                                                     'Caños del '
#                                                                     'Peral',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Ouh Babbo!',
#                                                      'osm_id': 1556708463,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 389,
#                               'district': 'Centro',
#                               'formatted': 'Ouh Babbo!, Calle de Caños del '
#                                            'Peral, 28013 Madrid, Spain',
#                               'lat': 40.4187577,
#                               'lon': -3.7086523,
#                               'name': 'Ouh Babbo!',
#                               'neighbourhood': 'Barrio de la Latina',
#                               'place_id': '51a5e1a5e551ab0dc0599fea31da99354440f00103f9016f7cc95c0000000092030a4f756820426162626f21',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Caños del Peral',
#                               'suburb': 'Palacio'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.706827899999999,
#                                             40.41976560032255],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'La Tagliatella',
#                               'address_line2': 'Calle Preciados, 36, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '+34 915229121'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 36,
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Calle '
#                                                                     'Preciados',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'La Tagliatella',
#                                                      'old_name': 'All U Can '
#                                                                  'Eat',
#                                                      'osm_id': 2046224575,
#                                                      'osm_type': 'n',
#                                                      'phone': '+34 915229121',
#                                                      'website': 'https://www.latagliatella.es/restaurantes/la-tagliatella-preciados/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 488,
#                               'district': 'Centro',
#                               'formatted': 'La Tagliatella, Calle Preciados, '
#                                            '36, 28013 Madrid, Spain',
#                               'housenumber': '36',
#                               'lat': 40.4197656,
#                               'lon': -3.7068279,
#                               'name': 'La Tagliatella',
#                               'name_other': {'old_name': 'All U Can Eat'},
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'old_name': 'All U Can Eat',
#                               'place_id': '51ed33d36295a70dc05982af12e1ba354440f00103f901bfe8f6790000000092030e4c61205461676c696174656c6c61',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle Preciados',
#                               'suburb': 'Sol',
#                               'website': 'https://www.latagliatella.es/restaurantes/la-tagliatella-preciados/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7077489999999993,
#                                             40.41987470032258],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Topolino',
#                               'address_line2': 'Calle Preciados, 50, 28013 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'contact': {'phone': '+34 91 542 55 55'},
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 50,
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Calle '
#                                                                     'Preciados',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Topolino',
#                                                      'osm_id': 2632252656,
#                                                      'osm_type': 'n',
#                                                      'phone': '+34 91 542 55 '
#                                                               '55',
#                                                      'website': 'https://www.topolino.es/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact'],
#                               'distance': 499,
#                               'district': 'Centro',
#                               'formatted': 'Topolino, Calle Preciados, 50, '
#                                            '28013 Madrid, Spain',
#                               'housenumber': '50',
#                               'lat': 40.4198747,
#                               'lon': -3.707749,
#                               'name': 'Topolino',
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'place_id': '51af36c64e78a90dc059d2264574be354440f00103f901f0fce49c00000000920308546f706f6c696e6f',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle Preciados',
#                               'suburb': 'Sol',
#                               'website': 'https://www.topolino.es/'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7068314000000004,
#                                             40.420573700322656],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Ginos',
#                               'address_line2': 'Gran Vía, 43, 28013 Madrid, '
#                                                'Spain',
#                               'brand': 'Ginos',
#                               'brand_details': {'wikidata': 'Q98503664'},
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 43,
#                                                      'addr:postcode': 28013,
#                                                      'addr:street': 'Gran Vía',
#                                                      'amenity': 'restaurant',
#                                                      'brand': 'Ginos',
#                                                      'brand:wikidata': 'Q98503664',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Ginos',
#                                                      'old_name': 'VIPS',
#                                                      'osm_id': 184049552,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.catering'],
#                               'distance': 577,
#                               'district': 'Centro',
#                               'formatted': 'Ginos, Gran Vía, 43, 28013 Madrid, '
#                                            'Spain',
#                               'housenumber': '43',
#                               'lat': 40.4205737,
#                               'lon': -3.7068314,
#                               'name': 'Ginos',
#                               'name_other': {'old_name': 'VIPS'},
#                               'neighbourhood': 'Malasaña',
#                               'old_name': 'VIPS',
#                               'place_id': '518449963897a70dc059c538e85bd5354440f00103f901905ff80a0000000092030547696e6f73',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Gran Vía',
#                               'suburb': 'Palacio'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.700878, 40.41721500032222],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Davvero',
#                               'address_line2': 'Calle de Alcalá, 12, 28014 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
# ...
#                               'name': 'Davvero',
#                               'neighbourhood': 'Barrio de los Austrias',
#                               'place_id': '5119e3c3ec659b0dc0596de4164d67354440f00103f9016b1f2962020000009203074461767665726f',
#                               'postcode': '28014',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Alcalá',
#                               'suburb': 'Sol',
#                               'website': 'https://davverorestaurante.com'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7004107000000004,
#                                             40.41503260032194],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Il Pezzo di Guiseppe',
#                               'address_line2': 'Plaza de Santa Ana, 5, 28012 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:housenumber': 5,
#                                                      'addr:postcode': 28012,
#                                                      'addr:street': 'Plaza de '
#                                                                     'Santa Ana',
#                                                      'amenity': 'restaurant',
#                                                      'contact:facebook': 'https://www.facebook.com/Il-Pezzo-di-Giuseppe-603413219720701/timeline/',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Il Pezzo di '
#                                                              'Guiseppe',
#                                                      'osm_id': 3757077744,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 592,
#                               'district': 'Centro',
#                               'formatted': 'Il Pezzo di Guiseppe, Plaza de '
#                                            'Santa Ana, 5, 28012 Madrid, Spain',
#                               'housenumber': '5',
#                               'lat': 40.4150326,
#                               'lon': -3.7004107,
#                               'name': 'Il Pezzo di Guiseppe',
#                               'neighbourhood': 'Barrio de las Letras',
#                               'place_id': '51d325d2ec709a0dc0590b94cac91f354440f00103f901f074f0df00000000920314496c2050657a7a6f206469204775697365707065',
#                               'postcode': '28012',
#                               'state': 'Community of Madrid',
#                               'street': 'Plaza de Santa Ana',
#                               'suburb': 'Cortes'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.7088761, 40.409460700321226],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Nina pasta bar',
#                               'address_line2': 'Calle de Santa Ana, 28005 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:street': 'Calle de '
#                                                                     'Santa Ana',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Nina pasta bar',
#                                                      'osm_id': 5986211285,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 671,
#                               'district': 'Centro',
#                               'formatted': 'Nina pasta bar, Calle de Santa '
#                                            'Ana, 28005 Madrid, Spain',
#                               'lat': 40.4094607,
#                               'lon': -3.7088761,
#                               'name': 'Nina pasta bar',
#                               'neighbourhood': 'Lavapiés',
#                               'place_id': '510554933bc7ab0dc0593f704e3569344440f00103f901d555ce640100000092030e4e696e6120706173746120626172',
#                               'postcode': '28005',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Santa Ana'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.6994791, 40.41396950032182],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Come Prima',
#                               'address_line2': 'Calle de Echegaray, 29, 28014 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:country': 'ES',
#                                                      'addr:housenumber': 29,
#                                                      'addr:postcode': 28014,
#                                                      'addr:street': 'Calle de '
#                                                                     'Echegaray',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Come Prima',
#                                                      'osm_id': 4237517691,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.catering'],
#                               'distance': 688,
#                               'district': 'Centro',
#                               'formatted': 'Come Prima, Calle de Echegaray, '
#                                            '29, 28014 Madrid, Spain',
#                               'housenumber': '29',
#                               'lat': 40.4139695,
#                               'lon': -3.6994791,
#                               'name': 'Come Prima',
#                               'neighbourhood': 'Barrio de las Letras',
#                               'place_id': '5155e2957f88980dc0593bb6dcf3fc344440f00103f9017b6393fc0000000092030a436f6d65205072696d61',
#                               'postcode': '28014',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de Echegaray',
#                               'suburb': 'Cortes'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.6993074999999997,
#                                             40.412731700321665],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'La Pizzateca',
#                               'address_line2': 'Calle del León, 35, 28014 '
#                                                'Madrid, Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian',
#                                              'catering.restaurant.pizza'],
#                               'catering': {'cuisine': 'italian_pizza'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Madrid',
#                                                      'addr:country': 'ES',
#                                                      'addr:housenumber': 35,
#                                                      'addr:postcode': 28014,
#                                                      'addr:street': 'Calle del '
#                                                                     'León',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian_pizza',
#                                                      'name': 'La Pizzateca',
#                                                      'opening_hours': 'Mo-Su '
#                                                                       '13:00-16:30, '
#                                                                       '19:00-24:00',
#                                                      'osm_id': 4785282921,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.catering'],
#                               'distance': 746,
#                               'district': 'Centro',
#                               'formatted': 'La Pizzateca, Calle del León, 35, '
#                                            '28014 Madrid, Spain',
#                               'housenumber': '35',
#                               'lat': 40.4127317,
#                               'lon': -3.6993075,
#                               'name': 'La Pizzateca',
#                               'neighbourhood': 'Barrio de las Letras',
#                               'opening_hours': 'Mo-Su 13:00-16:30, 19:00-24:00',
#                               'place_id': '51b8c7d2872e980dc059b7737164d4344440f00103f901699f391d0100000092030c4c612050697a7a6174656361',
#                               'postcode': '28014',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle del León',
#                               'suburb': 'Cortes'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-3.6997175000000007,
#                                             40.418734200322426],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Bresca',
#                               'address_line2': 'Calle de la Virgen de los '
#                                                'Peligros, 7, 28013 Madrid, '
#                                                'Spain',
#                               'categories': ['catering',
#                                              'catering.restaurant',
#                                              'catering.restaurant.italian'],
#                               'catering': {'cuisine': 'italian'},
#                               'city': 'Madrid',
#                               'country': 'Spain',
#                               'country_code': 'es',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': 7,
#                                                      'addr:street': 'Calle de '
#                                                                     'la Virgen '
#                                                                     'de los '
#                                                                     'Peligros',
#                                                      'amenity': 'restaurant',
#                                                      'cuisine': 'italian',
#                                                      'name': 'Brescia',
#                                                      'name:en': 'Bresca',
#                                                      'osm_id': 6628543886,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.catering'],
#                               'distance': 748,
#                               'district': 'Centro',
#                               'formatted': 'Bresca, Calle de la Virgen de los '
#                                            'Peligros, 7, 28013 Madrid, Spain',
#                               'housenumber': '7',
#                               'lat': 40.4187342,
#                               'lon': -3.6997175,
#                               'name': 'Brescia',
#                               'name_international': {'en': 'Bresca'},
#                               'neighbourhood': 'Barrio de las Letras',
#                               'place_id': '51d582177d05990dc059ff0c101599354440f00103f9018e8d178b0100000092030742726573636961',
#                               'postcode': '28013',
#                               'state': 'Community of Madrid',
#                               'street': 'Calle de la Virgen de los Peligros',
#                               'suburb': 'Sol'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print a message to follow up the restaurant search
print("Starting restaurant search")

# Iterate through the types_df DataFrame
for index, row in types_df.iterrows():
    
    # Get the ethnicity type from the current DataFrame's row
    ethnicity = row["ethnicity"]
    # Add the current ethnicity type to the parameters
    params = {
    "filter":filters,
    "limit":limit,
    "bias":bias,
    "categories": f"catering.restaurant.{ethnicity}",
    "apiKey":geoapify_key    
}
   
    # Make an API request using the params dictionary
    response= requests.get(base_url, params = params).json()
    
    # Convert the API response to JSON format
    
    
    # Grab the first restaurant from the results and store the details in the DataFrame
    try:

        types_df.loc[index,"name"] = response["features"][0]["properties"]["address_line1"]
        types_df.loc[index,"address"] = response["features"][0]["properties"]["address_line2"]
        types_df.loc[index,"distance"] = response["features"][0]["properties"]["distance"]
    except (KeyError, IndexError):
        # If no restaurant is found, set the restaurant name as "No restaurant found".
        types_df.loc[index, "name"] = "No restaurant found"
        # Set the distance column value to np.nan to allow sorting values
        types_df.loc[index, "distance"] = np.nan
        
    # Log the search results
    print(f"nearest {ethnicity} restaurant: {types_df.loc[index, 'name']}")

# Display sample data
types_df
# Out:
# Starting restaurant search
# nearest italian restaurant: La Fojetta
# nearest chinese restaurant: Tapas de Sichuan
# nearest mexican restaurant: Takos al Pastor
# nearest japanese restaurant: Sushi Bar
# nearest american restaurant: Foster's Hollywood
# nearest indian restaurant: Agra Palace
# nearest asian restaurant: Yatai Market
# nearest french restaurant: La Esquina del Real
# nearest german restaurant: No restaurant found
# nearest thai restaurant: Patong Thai
# nearest greek restaurant: Dionisos
# nearest tex-mex restaurant: No restaurant found
# nearest vietnamese restaurant: Viet Nam
# nearest turkish restaurant: Bósforos
# nearest korean restaurant: Gayagum
# nearest spanish restaurant: Cerveceria La Campana
# nearest lebanese restaurant: Byblos
# nearest indonesian restaurant: No restaurant found
# nearest portuguese restaurant: No restaurant found
# nearest arab restaurant: Be Beirut
# nearest russian restaurant: Rasputín
# nearest filipino restaurant: No restaurant found
# nearest african restaurant: Dakar
# nearest malaysian restaurant: No restaurant found
# nearest caribbean restaurant: No restaurant found
# nearest peruvian restaurant: Kechua
# nearest bavarian restaurant: No restaurant found
# nearest brazilian restaurant: No restaurant found
# nearest persian restaurant: No restaurant found
# nearest argentinian restaurant: De María Ópera
# nearest oriental restaurant: No restaurant found
# nearest balkan restaurant: No restaurant found
# nearest moroccan restaurant: No restaurant found
# nearest ethiopian restaurant: Gonder
# nearest taiwanese restaurant: No restaurant found
# nearest latin_american restaurant: Casa Jaguar
# nearest hawaiian restaurant: No restaurant found
# nearest irish restaurant: No restaurant found
# nearest austrian restaurant: No restaurant found
# nearest croatian restaurant: No restaurant found
# nearest danish restaurant: No restaurant found
# nearest bolivian restaurant: No restaurant found
# nearest hungarian restaurant: No restaurant found
# nearest european restaurant: No restaurant found
# nearest jamaican restaurant: No restaurant found
# nearest cuban restaurant: La Negra Tomasa
# nearest uzbek restaurant: No restaurant found
# nearest nepalese restaurant: No restaurant found
# nearest czech restaurant: No restaurant found
# nearest syrian restaurant: No restaurant found
# nearest afghan restaurant: No restaurant found
# nearest malay restaurant: No restaurant found
# nearest belgian restaurant: Rincón Bruxelles
# nearest ukrainian restaurant: No restaurant found
# nearest swedish restaurant: No restaurant found
# nearest pakistani restaurant: No restaurant found
#          ethnicity                   name  \
# 0          italian             La Fojetta
# 1          chinese       Tapas de Sichuan
# 2          mexican        Takos al Pastor
# 3         japanese              Sushi Bar
# 4         american     Foster's Hollywood
# 5           indian            Agra Palace
# 6            asian           Yatai Market
# 7           french    La Esquina del Real
# 8           german    No restaurant found
# 9             thai            Patong Thai
# 10           greek               Dionisos
# 11         tex-mex    No restaurant found
# 12      vietnamese               Viet Nam
# 13         turkish               Bósforos
# 14          korean                Gayagum
# 15         spanish  Cerveceria La Campana
# 16        lebanese                 Byblos
# 17      indonesian    No restaurant found
# 18      portuguese    No restaurant found
# 19            arab              Be Beirut
# 20         russian               Rasputín
# 21        filipino    No restaurant found
# 22         african                  Dakar
# 23       malaysian    No restaurant found
# 24       caribbean    No restaurant found
# 25        peruvian                 Kechua
# 26        bavarian    No restaurant found
# 27       brazilian    No restaurant found
# 28         persian    No restaurant found
# 29     argentinian         De María Ópera
# 30        oriental    No restaurant found
# 31          balkan    No restaurant found
# 32        moroccan    No restaurant found
# 33       ethiopian                 Gonder
# 34       taiwanese    No restaurant found
# 35  latin_american            Casa Jaguar
# 36        hawaiian    No restaurant found
# 37           irish    No restaurant found
# 38        austrian    No restaurant found
# 39        croatian    No restaurant found
# 40          danish    No restaurant found
# 41        bolivian    No restaurant found
# 42       hungarian    No restaurant found
# 43        european    No restaurant found
# 44        jamaican    No restaurant found
# 45           cuban        La Negra Tomasa
# 46           uzbek    No restaurant found
# 47        nepalese    No restaurant found
# 48           czech    No restaurant found
# 49          syrian    No restaurant found
# 50          afghan    No restaurant found
# 51           malay    No restaurant found
# 52         belgian       Rincón Bruxelles
# 53       ukrainian    No restaurant found
# 54         swedish    No restaurant found
# 55       pakistani    No restaurant found
#
#                                               address distance
# 0   Calle de la Escalerilla de Piedra, 2, 28005 Ma...       76
# 1          Cava de San Miguel, 3, 28005 Madrid, Spain      109
# 2             Calle Botoneras, 7, 28012 Madrid, Spain       86
# 3   Plaza del Comandante Las Morenas, 5, 28013 Mad...      141
# 4             Plaza de Isabel II, 28013 Madrid, Spain      343
# 5            Calle de Vergara, 7, 28013 Madrid, Spain      377
# 6    Calle de Doctor Cortezo, 10, 28012 Madrid, Spain      396
# 7        Calle de la Amnistía, 4, 28013 Madrid, Spain      333
# 8                                                          NaN
# 9            Calle de la Cruz, 7, 28012 Madrid, Spain      543
# 10            Calle del León, 17, 28014 Madrid, Spain      743
# 11                                                         NaN
# 12       Calle de las Huertas, 4, 28012 Madrid, Spain      553
# 13         Calle de Hortaleza, 6, 28004 Madrid, Spain      813
# 14        Calle de Bordadores, 7, 28013 Madrid, Spain      157
# 15            Calle Botoneras, 6, 28012 Madrid, Spain       76
# 16  Corredera Baja de San Pablo, 4, 28004 Madrid, ...      740
# 17                                                         NaN
# 18                                                         NaN
# 19         Calle de los Estudios, 28012 Madrid, Spain      365
# 20                 Calle Yeseros, 28005 Madrid, Spain      625
# 21                                                         NaN
# 22           Calle del Ave María, 28012 Madrid, Spain      783
# 23                                                         NaN
# 24                                                         NaN
# 25       Calle de las Fuentes, 9, 28013 Madrid, Spain      236
# 26                                                         NaN
# 27                                                         NaN
# 28                                                         NaN
# 29         Plaza de Isabel II, 2, 28013 Madrid, Spain      340
# 30                                                         NaN
# 31                                                         NaN
# 32                                                         NaN
# 33               Calle Grafal, 8, 28005 Madrid, Spain      255
# 34                                                         NaN
# 35   Calle de Caños del Peral, 9, 28013 Madrid, Spain      411
# 36                                                         NaN
# 37                                                         NaN
# 38                                                         NaN
# 39                                                         NaN
# 40                                                         NaN
# 41                                                         NaN
# 42                                                         NaN
# 43                                                         NaN
# 44                                                         NaN
# 45                Calle de Cádiz, 28012 Madrid, Spain      425
# 46                                                         NaN
# 47                                                         NaN
# 48                                                         NaN
# 49                                                         NaN
# 50                                                         NaN
# 51                                                         NaN
# 52              Calle del Espejo, 28013 Madrid, Spain      252
# 53                                                         NaN
# 54                                                         NaN
# 55                                                         NaN

# %%
# Sort restuls by distance
types_df = types_df.sort_values(by=["distance"])

# Display the top 10 nearest restaurants
types_df.head(10)
# Out:
#     ethnicity                   name  \
# 0     italian             La Fojetta
# 15    spanish  Cerveceria La Campana
# 2     mexican        Takos al Pastor
# 1     chinese       Tapas de Sichuan
# 3    japanese              Sushi Bar
# 14     korean                Gayagum
# 25   peruvian                 Kechua
# 52    belgian       Rincón Bruxelles
# 33  ethiopian                 Gonder
# 7      french    La Esquina del Real
#
#                                               address distance
# 0   Calle de la Escalerilla de Piedra, 2, 28005 Ma...       76
# 15            Calle Botoneras, 6, 28012 Madrid, Spain       76
# 2             Calle Botoneras, 7, 28012 Madrid, Spain       86
# 1          Cava de San Miguel, 3, 28005 Madrid, Spain      109
# 3   Plaza del Comandante Las Morenas, 5, 28013 Mad...      141
# 14        Calle de Bordadores, 7, 28013 Madrid, Spain      157
# 25       Calle de las Fuentes, 9, 28013 Madrid, Spain      236
# 52              Calle del Espejo, 28013 Madrid, Spain      252
# 33               Calle Grafal, 8, 28005 Madrid, Spain      255
# 7        Calle de la Amnistía, 4, 28013 Madrid, Spain      333
