# %% [markdown]
# # Geoapify Places Demo

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# %%
# Set the geographical coordinates for Sydney, Australia
lat = -33.8698439
lon = 151.2082848

# Set the parameters for the type of place
cat = "catering.restaurant"
type = "vegetarian"
radius = 8000

# Set the parameters for the type of search
filter = f"circle:{lon},{lat},{radius}"
bias = f"proximity:{lon},{lat}"
limit = 20

# set up a parameters dictionary

params = {"categories": cat,
          "conditions": type,
          "limit": limit,
          "filter": filter, 
          "bias": bias, 
          "apiKey": geoapify_key}
# Set base URL

base_url = "https://api.geoapify.com/v2/places"
# run a request using our params dictionary

response = requests.get(base_url, params=params).json()

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key

# %%
# convert response to json


# Print the json (pretty printed)
print(json.dumps(response, indent = 4, sort_keys = True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2080336,
#                     -33.87648089966814
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Macchiato",
#                 "address_line2": "338 Pitt Street, Sydney NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.limited"
#                 ],
#                 "catering": {
#                     "cuisine": "pizza",
#                     "diet": {
#                         "vegan": false,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2023-07-24",
#                         "cuisine": "pizza",
#                         "diet:vegan": "no",
#                         "diet:vegetarian": "yes",
#                         "name": "Macchiato",
#                         "opening_hours:signed": "no",
#                         "osm_id": 4021091492,
#                         "osm_type": "n",
#                         "wheelchair": "limited"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 737,
#                 "district": "Koreatown",
#                 "facilities": {
#                     "wheelchair": true,
#                     "wheelchair_details": {
#                         "condition": "limited"
#                     }
#                 },
#                 "formatted": "Macchiato, 338 Pitt Street, Sydney NSW 2000, Australia",
#                 "housenumber": "338",
#                 "lat": -33.8764809,
#                 "lon": 151.2080336,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Macchiato",
#                 "place_id": "51038f1436a8e662405958d2af8630f040c0f00103f901a4fcacef000000009203094d616363686961746f",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Pitt Street",
#                 "suburb": "Sydney"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2043797,
#                     -33.87599289966807
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sushi Rio",
#                 "address_line2": "Liverpool Street, Sydney NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Sushi Rio",
#                         "opening_hours": "Su-Th 12:00-21:00; Fr,Sa 12:00-22:00",
#                         "osm_id": 4021093289,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "smoking": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 772,
#                 "district": "Koreatown",
#                 "facilities": {
#                     "outdoor_seating": false,
#                     "smoking": false
#                 },
#                 "formatted": "Sushi Rio, Liverpool Street, Sydney NSW 2000, Australia",
#                 "lat": -33.8759929,
#                 "lon": 151.2043797,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Sushi Rio",
#                 "opening_hours": "Su-Th 12:00-21:00; Fr,Sa 12:00-22:00",
#                 "place_id": "51ecee4b478ae662405921cd0b8920f040c0f00103f901a903adef0000000092030953757368692052696f",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Liverpool Street",
#                 "suburb": "Sydney"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.21795079999998,
#                     -33.86765929966658
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "MOD. Dining",
#                 "address_line2": "Cowper Wharf Road Offramp, Sydney NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date": "2023-03-04",
#                         "contact:instagram": "moddiningbyclaytonwells",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "MOD. Dining",
#                         "osm_id": 10708183273,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "reservation": "no",
#                         "website": "https://www.moddining.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 927,
#                 "district": "Quay Quarter",
#                 "facilities": {
#                     "outdoor_seating": true
#                 },
#                 "formatted": "MOD. Dining, Cowper Wharf Road Offramp, Sydney NSW 2000, Australia",
#                 "lat": -33.8676593,
#                 "lon": 151.2179508,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "MOD. Dining",
#                 "payment_options": {
#                     "credit_cards": true,
#                     "debit_cards": true
#                 },
#                 "place_id": "5162c4f473f9e6624059b111be750fef40c0f00103f901e9e8417e0200000092030b4d4f442e2044696e696e67",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Cowper Wharf Road Offramp",
#                 "suburb": "Sydney",
#                 "website": "https://www.moddining.com.au/"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1969468,
#                     -33.86967229966693
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Jumbo Thai",
#                 "address_line2": "Union Street Cycleway, Pyrmont NSW 2009, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.thai",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "thai",
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "thai",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Jumbo Thai",
#                         "opening_hours": "Mo-Su 10:00-21:00",
#                         "osm_id": 4448583527,
#                         "osm_type": "n",
#                         "outdoor_seating": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1049,
#                 "facilities": {
#                     "outdoor_seating": false
#                 },
#                 "formatted": "Jumbo Thai, Union Street Cycleway, Pyrmont NSW 2009, Australia",
#                 "lat": -33.8696723,
#                 "lon": 151.1969468,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Jumbo Thai",
#                 "opening_hours": "Mo-Su 10:00-21:00",
#                 "place_id": "51a92160634de66240593ea7026c51ef40c0f00103f90167ff27090100000092030a4a756d626f2054686169",
#                 "postcode": "2009",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Union Street Cycleway",
#                 "suburb": "Pyrmont"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2024953,
#                     -33.87804939966843
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Hakatamon Ramen",
#                 "address_line2": "81-83 Harbour Street, Haymarket NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.japanese",
#                     "catering.restaurant.ramen",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "japanese;ramen",
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "contact:facebook": "hakatamondarlingsquare",
#                         "cuisine": "japanese;ramen",
#                         "diet:vegetarian": "yes",
#                         "name": "Hakatamon Ramen",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9480685417,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "smoking": "no",
#                         "survey:date": "2022-02-05"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1056,
#                 "district": "Chinatown",
#                 "facilities": {
#                     "outdoor_seating": true,
#                     "smoking": false
#                 },
#                 "formatted": "Hakatamon Ramen, 81-83 Harbour Street, Haymarket NSW 2000, Australia",
#                 "housenumber": "81-83",
#                 "lat": -33.8780494,
#                 "lon": 151.2024953,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Hakatamon Ramen",
#                 "place_id": "5100636cd77ae662405996ec37ec63f040c0f00103f90169c717350200000092030f48616b6174616d6f6e2052616d656e",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Harbour Street",
#                 "suburb": "Haymarket"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.192878,
#                     -33.866840799666434
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Yuzu",
#                 "address_line2": "1 Scott Street, Pyrmont NSW 2009, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.japanese",
#                     "vegan",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "catering": {
#                     "cuisine": "japanese",
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "japanese",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Yuzu",
#                         "opening_hours": "Mo-Fr 11:30-09:30, Sa 05:30-09:30; Su off",
#                         "osm_id": 2874264581,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1464,
#                 "facilities": {
#                     "wheelchair": true
#                 },
#                 "formatted": "Yuzu, 1 Scott Street, Pyrmont NSW 2009, Australia",
#                 "housenumber": "1",
#                 "lat": -33.8668408,
#                 "lon": 151.192878,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Yuzu",
#                 "opening_hours": "Mo-Fr 11:30-09:30, Sa 05:30-09:30; Su off",
#                 "place_id": "51c6c37b0e2ce6624059f2b3aaa3f4ee40c0f00103f90105cc51ab0000000092030459757a75",
#                 "postcode": "2009",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Scott Street",
#                 "suburb": "Pyrmont"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.21620127431757,
#                     -33.882061699669144
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Dead Ringer",
#                 "address_line2": "413 Bourke Street, Surry Hills NSW 2010, Australia",
#                 "building": {
#                     "levels": 3
#                 },
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "diet": {
#                         "vegetarian": true
#                     },
#                     "reservation": "required"
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 413,
#                         "addr:street": "Bourke Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "building:levels": 3,
#                         "check_date": "2023-03-18",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Dead Ringer",
#                         "osm_id": 556386885,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "reservation": "yes",
#                         "website": "https://www.deadringersydney.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 1529,
#                 "district": "Strawberry Hills",
#                 "facilities": {
#                     "outdoor_seating": true
#                 },
#                 "formatted": "Dead Ringer, 413 Bourke Street, Surry Hills NSW 2010, Australia",
#                 "housenumber": "413",
#                 "lat": -33.8820617,
#                 "lon": 151.2162012743176,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Dead Ringer",
#                 "payment_options": {
#                     "credit_cards": true,
#                     "debit_cards": true
#                 },
#                 "place_id": "518551ef1eebe66240590b91d465e7f040c0f00102f90145ca29210000000092030b446561642052696e676572",
#                 "postcode": "2010",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Bourke Street",
#                 "suburb": "Surry Hills",
#                 "website": "https://www.deadringersydney.com.au/"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.19680242896865,
#                     -33.88054714966888
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Dumpling & Noodle House",
#                 "address_line2": "430 Wattle Street, Ultimo NSW 2007, Australia",
#                 "building": {
#                     "levels": 2,
#                     "type": "house"
#                 },
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.residential",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.dumpling",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "chinese;dumplings;noodle",
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 430,
#                         "addr:postcode": 2007,
#                         "addr:state": "NSW",
#                         "addr:street": "Wattle Street",
#                         "addr:suburb": "Ultimo",
#                         "amenity": "restaurant",
#                         "building": "house",
#                         "building:levels": 2,
#                         "cuisine": "chinese;dumplings;noodle",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Dumpling & Noodle House",
#                         "opening_hours": "PH,Mo-Su 10:00-22:00",
#                         "osm_id": 1047327174,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "smoking": "no",
#                         "wheelchair": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1583,
#                 "facilities": {
#                     "outdoor_seating": true,
#                     "smoking": false,
#                     "wheelchair": false
#                 },
#                 "formatted": "Dumpling & Noodle House, 430 Wattle Street, Ultimo NSW 2007, Australia",
#                 "housenumber": "430",
#                 "lat": -33.88054715,
#                 "lon": 151.19680242896868,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Dumpling & Noodle House",
#                 "opening_hours": "PH,Mo-Su 10:00-22:00",
#                 "place_id": "5133869b344ce6624059f934ddc4b5f040c0f00102f901c6f16c3e0000000092031744756d706c696e672026204e6f6f646c6520486f757365",
#                 "postcode": "2007",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Wattle Street",
#                 "suburb": "Ultimo"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.22556049999997,
#                     -33.87230589966741
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Maggie's",
#                 "address_line2": "50 Macleay Street, Elizabeth Bay NSW 2011, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.austrian",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "austrian",
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "contact": {
#                     "email": "hello@maggiespottspoint.com.au",
#                     "phone": "+61 2 9331 2226"
#                 },
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 50,
#                         "addr:street": "Macleay Street",
#                         "addr:unit": "Shop 7",
#                         "amenity": "restaurant",
#                         "cuisine": "austrian",
#                         "delivery": "yes",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "email": "hello@maggiespottspoint.com.au",
#                         "name": "Maggie's",
#                         "osm_id": 10824244363,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "phone": "+61 2 9331 2226",
#                         "website": "https://www.maggiespottspoint.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 1622,
#                 "facilities": {
#                     "delivery": true,
#                     "outdoor_seating": true
#                 },
#                 "formatted": "Maggie's, 50 Macleay Street, Elizabeth Bay NSW 2011, Australia",
#                 "housenumber": "50",
#                 "lat": -33.8723059,
#                 "lon": 151.2255605,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Maggie's",
#                 "place_id": "519e58a7ca37e7624059f6963fb8a7ef40c0f00103f9018bdc2c85020000009203084d61676769652773",
#                 "postcode": "2011",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Macleay Street",
#                 "suburb": "Elizabeth Bay",
#                 "website": "https://www.maggiespottspoint.com.au"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2138725,
#                     -33.88675009966996
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Nour",
#                 "address_line2": "490 Crown Street, Surry Hills NSW 2010, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.arab",
#                     "catering.restaurant.lebanese",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "arab;lebanese",
#                     "diet": {
#                         "meat": true,
#                         "vegetarian": true
#                     },
#                     "reservation": "recommended"
#                 },
#                 "city": "Sydney",
#                 "contact": {
#                     "phone": "+61 2 9331 3413"
#                 },
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 490,
#                         "addr:postcode": 2010,
#                         "addr:state": "NSW",
#                         "addr:street": "Crown Street",
#                         "addr:suburb": "Surry Hills",
#                         "addr:unit": "Shop 3",
#                         "amenity": "restaurant",
#                         "cuisine": "arab;lebanese",
#                         "diet:meat": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Nour",
#                         "opening_hours": "Tu-Sa 18:00-22:00, Fr-Sa 12:00-14:30, Su 10:00-14:30",
#                         "osm_id": 8109734733,
#                         "osm_type": "n",
#                         "phone": "+61 2 9331 3413",
#                         "reservation": "recommended",
#                         "website": "https://noursydney.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "distance": 1945,
#                 "district": "Strawberry Hills",
#                 "formatted": "Nour, 490 Crown Street, Surry Hills NSW 2010, Australia",
#                 "housenumber": "490",
#                 "lat": -33.8867501,
#                 "lon": 151.2138725,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Nour",
#                 "opening_hours": "Tu-Sa 18:00-22:00, Fr-Sa 12:00-14:30, Su 10:00-14:30",
#                 "place_id": "517120240bd8e662405953e7fa0681f140c0f00103f9014dbb60e3010000009203044e6f7572",
#                 "postcode": "2010",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Crown Street",
#                 "suburb": "Surry Hills",
#                 "website": "https://noursydney.com/"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2104967,
#                     -33.84378949966237
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "ANCHOR Cafe & Restaurant",
#                 "address_line2": "118 Alfred Street South, Milsons Point NSW 2061, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "gluten_free",
#                     "internet_access",
#                     "vegan",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "catering": {
#                     "cuisine": "pizza;italian;coffee_shop;ice_cream;seafood",
#                     "diet": {
#                         "gluten_free": true,
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "contact": {
#                     "email": "info@anchorrestaurant.com.au",
#                     "phone": "+61 2 9922 2996"
#                 },
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 118,
#                         "addr:postcode": 2061,
#                         "addr:state": "NSW",
#                         "addr:street": "Alfred Street South",
#                         "addr:suburb": "Milsons Point",
#                         "amenity": "restaurant",
#                         "cuisine": "pizza;italian;coffee_shop;ice_cream;seafood",
#                         "delivery": "yes",
#                         "diet:gluten_free": "yes",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "email": "info@anchorrestaurant.com.au",
#                         "internet_access": "wlan",
#                         "name": "ANCHOR Cafe & Restaurant",
#                         "opening_hours": "Mo-Su 17:00-21:30",
#                         "osm_id": 6332613852,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "phone": "+61 2 9922 2996",
#                         "website": "https://anchorrestaurant.com.au/",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 2897,
#                 "district": "Lower North Shore",
#                 "facilities": {
#                     "delivery": true,
#                     "internet_access": true,
#                     "outdoor_seating": true,
#                     "wheelchair": true
#                 },
#                 "formatted": "ANCHOR Cafe & Restaurant, 118 Alfred Street South, Milsons Point NSW 2061, Australia",
#                 "housenumber": "118",
#                 "lat": -33.8437895,
#                 "lon": 151.2104967,
#                 "municipality": "North Sydney Council",
#                 "name": "ANCHOR Cafe & Restaurant",
#                 "opening_hours": "Mo-Su 17:00-21:30",
#                 "place_id": "514f4d9363bce662405909e1584b01ec40c0f00103f901dc04747901000000920318414e43484f52204361666520262052657374617572616e74",
#                 "postcode": "2061",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Alfred Street South",
#                 "suburb": "Milsons Point",
#                 "website": "https://anchorrestaurant.com.au/"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.17832789999997,
#                     -33.85669719966464
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Rosso Pomodoro",
#                 "address_line2": "Darling Street, Balmain NSW 2041, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.italian",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "italian",
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "italian",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Rosso Pomodoro",
#                         "opening_hours": "Tu-Su 17:00-22:00+",
#                         "osm_id": 10259175095,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "smoking": "no",
#                         "wheelchair": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 3132,
#                 "district": "Inner West",
#                 "facilities": {
#                     "outdoor_seating": false,
#                     "smoking": false,
#                     "wheelchair": false
#                 },
#                 "formatted": "Rosso Pomodoro, Darling Street, Balmain NSW 2041, Australia",
#                 "lat": -33.8566972,
#                 "lon": 151.1783279,
#                 "municipality": "Inner West Council",
#                 "name": "Rosso Pomodoro",
#                 "opening_hours": "Tu-Su 17:00-22:00+",
#                 "payment_options": {
#                     "credit_cards": true,
#                     "debit_cards": true
#                 },
#                 "place_id": "51db4eb6dcb4e56240593491fb40a8ed40c0f00103f901b7967e630200000092030e526f73736f20506f6d6f646f726f",
#                 "postcode": "2041",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Darling Street",
#                 "suburb": "Balmain"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.22366449999998,
#                     -33.909090899673956
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Ogalo",
#                 "address_line2": "Anzac Parade, Kensington NSW 2033, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.portuguese",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "portuguese",
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "contact": {
#                     "phone": "+61 2 9662 6198"
#                 },
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "portuguese",
#                         "description": "Portuguese Style Chicken & Burgers",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Ogalo",
#                         "opening_hours": "PH,Mo-Su 10:00-22:00",
#                         "osm_id": 6548736881,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "phone": "+61 2 9662 6198",
#                         "smoking": "no",
#                         "website": "https://www.ogalo.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "description": "Portuguese Style Chicken & Burgers",
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 4580,
#                 "district": "Eastern Suburbs",
#                 "facilities": {
#                     "outdoor_seating": false,
#                     "smoking": false
#                 },
#                 "formatted": "Ogalo, Anzac Parade, Kensington NSW 2033, Australia",
#                 "lat": -33.9090909,
#                 "lon": 151.2236645,
#                 "municipality": "Randwick City Council",
#                 "name": "Ogalo",
#                 "opening_hours": "PH,Mo-Su 10:00-22:00",
#                 "place_id": "51d618744228e76240596e9831175df440c0f00103f90171cb5586010000009203054f67616c6f",
#                 "postcode": "2033",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Anzac Parade",
#                 "suburb": "Kensington",
#                 "website": "https://www.ogalo.com.au/"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.20221629999998,
#                     -33.827129299659425
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Montezuma's",
#                 "address_line2": "51 Alexander Street, Crows Nest NSW 2065, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.mexican",
#                     "gluten_free",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "mexican",
#                     "diet": {
#                         "gluten_free": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "contact": {
#                     "phone": "+61 2 9901 3533"
#                 },
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 51,
#                         "addr:postcode": 2065,
#                         "addr:state": "NSW",
#                         "addr:street": "Alexander Street",
#                         "addr:suburb": "Crows Nest",
#                         "amenity": "restaurant",
#                         "contact:facebook": "https://www.facebook.com/montezumasmexican/",
#                         "cuisine": "mexican",
#                         "delivery": "yes",
#                         "diet:gluten_free": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Montezuma's",
#                         "osm_id": 6836160011,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "phone": "+61 2 9901 3533",
#                         "start_date": 1978,
#                         "takeaway": "yes",
#                         "website": "https://www.montezumascrowsnest.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 4771,
#                 "district": "Lower North Shore",
#                 "facilities": {
#                     "delivery": true,
#                     "outdoor_seating": true,
#                     "takeaway": true
#                 },
#                 "formatted": "Montezuma's, 51 Alexander Street, Crows Nest NSW 2065, Australia",
#                 "housenumber": "51",
#                 "lat": -33.8271293,
#                 "lon": 151.2022163,
#                 "municipality": "North Sydney Council",
#                 "name": "Montezuma's",
#                 "neighbourhood": "Crows Nest Junction",
#                 "place_id": "51fa66518e78e6624059e1cc755fdfe940c0f00103f9010b8677970100000092030b4d6f6e74657a756d612773",
#                 "postcode": "2065",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Alexander Street",
#                 "suburb": "Crows Nest",
#                 "website": "https://www.montezumascrowsnest.com.au"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2290173124179,
#                     -33.82892729965975
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Nilgiri's",
#                 "address_line2": "283 Military Road, Cremorne NSW 2090, Australia",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.indian",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "indian",
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "contact": {
#                     "phone": "+61 2 9909 0063"
#                 },
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 283,
#                         "addr:postcode": 2090,
#                         "addr:state": "NSW",
#                         "addr:street": "Military Road",
#                         "addr:suburb": "Cremorne",
#                         "addr:unit": 3,
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "indian",
#                         "diet:vegetarian": "yes",
#                         "name": "Nilgiri's",
#                         "opening_hours": "We-Su 17:30-21:30",
#                         "osm_id": 1226063927,
#                         "osm_type": "w",
#                         "phone": "+61 2 9909 0063",
#                         "website": "https://nilgiris.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "distance": 4920,
#                 "district": "Lower North Shore",
#                 "formatted": "Nilgiri's, 283 Military Road, Cremorne NSW 2090, Australia",
#                 "housenumber": "283",
#                 "lat": -33.828927300000004,
#                 "lon": 151.2290173124179,
#                 "municipality": "North Sydney Council",
#                 "name": "Nilgiri's",
#                 "opening_hours": "We-Su 17:30-21:30",
#                 "place_id": "51b0611d1c54e76240596e662d4a1aea40c0f00102f90137401449000000009203094e696c676972692773",
#                 "postcode": "2090",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Military Road",
#                 "suburb": "Cremorne",
#                 "website": "https://nilgiris.com.au/"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.22411759999997,
#                     -33.912391699674544
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sushi Tengoku",
#                 "address_line2": "Anzac Parade, Kensington NSW 2033, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.japanese",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "cuisine": "japanese",
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "japanese",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Sushi Tengoku",
#                         "opening_hours": "Tu-Su 17:00-21:00, Fr-Su 11:30-15:00",
#                         "osm_id": 5678653702,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "smoking": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 4941,
#                 "district": "Eastern Suburbs",
#                 "facilities": {
#                     "outdoor_seating": false,
#                     "smoking": false
#                 },
#                 "formatted": "Sushi Tengoku, Anzac Parade, Kensington NSW 2033, Australia",
#                 "lat": -33.9123917,
#                 "lon": 151.2241176,
#                 "municipality": "Randwick City Council",
#                 "name": "Sushi Tengoku",
#                 "opening_hours": "Tu-Su 17:00-21:00, Fr-Su 11:30-15:00",
#                 "place_id": "51a74eacf82be76240593c9f4f40c9f440c0f00103f901066179520100000092030d53757368692054656e676f6b75",
#                 "postcode": "2033",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Anzac Parade",
#                 "suburb": "Kensington"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1620293,
#                     -33.90974279967406
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pizza Madre",
#                 "address_line2": "Sydenham Road, Marrickville NSW 2204, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "vegetarian",
#                     "vegetarian.only"
#                 ],
#                 "catering": {
#                     "cuisine": "pizza",
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "pizza",
#                         "diet:vegetarian": "only",
#                         "name": "Pizza Madre",
#                         "osm_id": 5708242227,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering"
#                 ],
#                 "distance": 6156,
#                 "district": "Inner West",
#                 "formatted": "Pizza Madre, Sydenham Road, Marrickville NSW 2204, Australia",
#                 "lat": -33.9097428,
#                 "lon": 151.1620293,
#                 "municipality": "Inner West Council",
#                 "name": "Pizza Madre",
#                 "place_id": "51cd0f12582fe5624059902fba7372f440c0f00103f90133dd3c540100000092030b50697a7a61204d61647265",
#                 "postcode": "2204",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Sydenham Road",
#                 "suburb": "Marrickville"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2730714,
#                     -33.85554939966445
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Vaucluse Tearooms",
#                 "address_line2": "Olola Avenue, Vaucluse NSW 2030, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian"
#                 ],
#                 "catering": {
#                     "diet": {
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "diet:vegetarian": "yes",
#                         "name": "Vaucluse Tearooms",
#                         "name:en": "Vaucluse Tearooms",
#                         "opening_hours": "We-Fr 10:00-16:30; Sa-Su 08:00-16:30",
#                         "osm_id": 4700348590,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering"
#                 ],
#                 "distance": 6201,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Vaucluse Tearooms, Olola Avenue, Vaucluse NSW 2030, Australia",
#                 "lat": -33.8555494,
#                 "lon": 151.2730714,
#                 "municipality": "Woollahra Municipal Council",
#                 "name": "Vaucluse Tearooms",
#                 "name_international": {
#                     "en": "Vaucluse Tearooms"
#                 },
#                 "opening_hours": "We-Fr 10:00-16:30; Sa-Su 08:00-16:30",
#                 "place_id": "51228f3b00bde8624059ebd589a482ed40c0f00103f901aea0291801000000920311566175636c75736520546561726f6f6d73",
#                 "postcode": "2030",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Olola Avenue",
#                 "suburb": "Vaucluse"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1772724,
#                     -33.93170949967801
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Bar Corretto",
#                 "address_line2": "Shiers Avenue, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "catering": {
#                     "diet": {
#                         "vegan": false,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2022-07-22",
#                         "diet:vegan": "no",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "level": 1,
#                         "name": "Bar Corretto",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9903332410,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "smoking": "no",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 7438,
#                 "facilities": {
#                     "outdoor_seating": false,
#                     "smoking": false,
#                     "wheelchair": true
#                 },
#                 "formatted": "Bar Corretto, Shiers Avenue, Mascot NSW 2020, Australia",
#                 "lat": -33.9317095,
#                 "lon": 151.1772724,
#                 "name": "Bar Corretto",
#                 "payment_options": {
#                     "credit_cards": true,
#                     "debit_cards": true
#                 },
#                 "place_id": "51780f2b37ace5624059aa3ec34142f740c0f00103f9013adc484e0200000092030c42617220436f72726574746f",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Shiers Avenue",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.17806459999997,
#                     -33.93242959967813
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Wok on Air",
#                 "address_line2": "Shiers Avenue, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegan",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "catering": {
#                     "diet": {
#                         "vegan": true,
#                         "vegetarian": true
#                     }
#                 },
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2023-11-30",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "level": 1,
#                         "name": "Wok on Air",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9821921615,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "smoking": "no",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 7484,
#                 "facilities": {
#                     "outdoor_seating": false,
#                     "smoking": false,
#                     "wheelchair": true
#                 },
#                 "formatted": "Wok on Air, Shiers Avenue, Mascot NSW 2020, Australia",
#                 "lat": -33.9324296,
#                 "lon": 151.1780646,
#                 "name": "Wok on Air",
#                 "payment_options": {
#                     "credit_cards": true,
#                     "debit_cards": true
#                 },
#                 "place_id": "51683288b4b2e5624059503866da59f740c0f00103f9014fa16e490200000092030a576f6b206f6e20416972",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Shiers Avenue",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Print the name and address of the first restaurant that appears
print(response["features"][0]["properties"]["address_line1"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# Macchiato
# 338 Pitt Street, Sydney NSW 2000, Australia
